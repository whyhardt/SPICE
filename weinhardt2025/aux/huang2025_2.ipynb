# %%
#!pip install -e SPICE --no-deps

# %%
# !ls ~/SPICE/examples/
# Out:
# ls: cannot access '/home/daniel/SPICE/examples/': No such file or directory

# %%
#!git clone https://github.com/whyhardt/SPICE.git

# %%
#!git clone https://github.com/whyhardt/SPICE.git
# !python --version

import sys
import os

# 1. Get the absolute path to your cloned folder
# Assuming the folder 'SPICE' is in your current working directory
project_root = os.path.abspath("SPICE")

# 2. Check for the likely internal structure
# Many modern packages hide the actual code inside a 'src' folder
if os.path.exists(os.path.join(project_root, "src")):
    package_path = os.path.join(project_root, "src")
else:
    package_path = project_root

if package_path not in sys.path:
    sys.path.append(package_path)
    print(f"✅ Added {package_path} to system path")

# 4. Now try the import
try:
    from spice.estimator import SpiceEstimator
    print("✅ Success! SpiceEstimator imported.")
except ImportError as e:
    print(f"❌ Still failing. Debug info below:")
    print(f"Contents of {package_path}: {os.listdir(package_path)}")
    raise e
# Out:
# Python 3.11.13
# ✅ Added /home/daniel/repositories/SPICE/weinhardt2025/aux/SPICE to system path
# ✅ Success! SpiceEstimator imported.

# %%
import pandas as pd
import numpy as np
from typing import Dict, List, Tuple
import matplotlib.pyplot as plt

from spice.estimator import SpiceEstimator
from spice.resources.spice_utils import SpiceConfig
from spice.utils.convert_dataset import convert_dataset
from spice.resources.rnn import BaseRNN

# For custom RNN
import torch
import torch.nn as nn

# %%
# Load your hover data
dataset = convert_dataset(
    file='../data/huang2025/huang2025.csv',
    df_participant_id = "subject_ID",
    df_block ='currentRound',
    df_choice = 'hover_tile_index',
    df_reward = 'score',
    additional_inputs = ['partner_tile_index', 'sample_number']
    )

# structure of dataset:
# dataset has two main attributes: xs -> inputs; ys -> targets (next action)
# shape: (n_participants*n_blocks*n_experiments, n_timesteps, features)
# features are (n_actions * action, n_actions * reward, n_additional_inputs * additional_input, block_number, experiment_id, participant_id)


# in order to set up the participant embedding we have to compute the number of unique participants in our data 
# to get the number of participants n_participants we do:
n_participants = len(dataset.xs[..., -1].unique())
n_actions = dataset.ys.shape[-1]

# %%
spice_config = SpiceConfig(
    library_setup={
        'visited_self': [],
        'visited_partner': [],
        'not_visited': [],
    },
    
    memory_state={
        'value_tile': 0,
    },
)

# %%
class HoverRNN(BaseRNN):
    """
    Custom RNN for modeling hover behavior.

    CRITICAL: Must match the interface expected by SPICE!
    The RNN should:
    - Take input of shape (batch, seq_len, input_size)
    - Return output of shape (batch, seq_len, output_size)
    - Optionally return hidden states
    """

    def __init__(self, spice_config, n_actions, n_participants, **kwargs):
        super(HoverRNN, self).__init__(
            spice_config=spice_config,
            n_actions=n_actions, 
            n_participants=n_participants, 
            embedding_size=32,
            sindy_polynomial_degree=2,
            )

        dropout = 0.1
        
        self.participant_embedding = self.setup_embedding(n_participants, self.embedding_size, dropout=dropout)
        
        # Value learning module (slow updates)
        # Can use recent reward history to modulate learning
        self.setup_module(key_module='visited_self', input_size=self.embedding_size, dropout=dropout)
        self.setup_module(key_module='visited_partner', input_size=self.embedding_size, dropout=dropout)
        self.setup_module(key_module='not_visited', input_size=self.embedding_size, dropout=dropout)
        
    def forward(self, inputs, prev_state=None, batch_first=False):
        """
        Forward pass.

        Args:
            inputs: Tuple containing (actions, rewards, additional_inputs, participant_ids)
            prev_state: Optional previous hidden state
            batch_first: Whether first dimension is batch (True) or timesteps (False)

        Returns:
            logits: (batch, seq_len, n_actions) - Action logits for each tile
            state: Updated hidden state dictionary
        """

        # Initialize inputs, outputs, and timesteps
        spice_signals = self.init_forward_pass(inputs, prev_state, batch_first)

        nan_mask = spice_signals.actions.isnan()
        tiles_visited_partner = spice_signals.additional_inputs[..., 0].nan_to_num(0).long()
        actions_partner = torch.nn.functional.one_hot(tiles_visited_partner, num_classes=self.n_actions)
        actions_partner = torch.where(nan_mask, torch.nan, actions_partner)
        actions_not_visited = 1 - (spice_signals.actions + actions_partner)
        
        # Get participant embeddings
        participant_embedding = self.participant_embedding(spice_signals.participant_ids)
        
        # Main loop: process each timestep
        for timestep in spice_signals.timesteps:
            
            # Update value for tile visited by self
            self.call_module(
                key_module='visited_self',
                key_state='value_tile',
                action_mask=spice_signals.actions[timestep],
                inputs=None,
                participant_embedding=participant_embedding,
                participant_index=spice_signals.participant_ids,
            )
            
            # Update value for tile visited by partner
            self.call_module(
                key_module='visited_partner',
                key_state='value_tile',
                action_mask=actions_partner[timestep],
                inputs=None,
                participant_embedding=participant_embedding,
                participant_index=spice_signals.participant_ids,
            )
            
            self.call_module(
                key_module='not_visited',
                key_state='value_tile',
                action_mask=actions_not_visited[timestep],
                inputs=None,
                participant_embedding=participant_embedding,
                participant_index=spice_signals.participant_ids,
            )
            
            # Apply beta parameters for each tile and compute logits
            spice_signals.logits[timestep] = self.state['value_tile']
        
        # Post-process the forward pass
        spice_signals = self.post_forward_pass(spice_signals, batch_first)

        return spice_signals.logits, self.get_state()

# %%
path_spice = 'spice_huang2025.pkl'

estimator = SpiceEstimator(
        device = torch.device("cuda"),
        # SPICE parameters
        rnn_class=HoverRNN,
        spice_config=spice_config,
        n_actions=n_actions,
        n_participants=n_participants,
        
        # rnn training parameters
        epochs=1000, # better: 4000 or 5000
        warmup_steps=1000,
        learning_rate=0.01,
        batch_size=512,
        bagging=True,
        
        # sindy fitting parameters
        sindy_weight=0.001,
        sindy_threshold=0.05,
        sindy_threshold_frequency=1,
        sindy_threshold_terms=1,
        sindy_cutoff_patience=100,
        sindy_epochs=1000,
        sindy_alpha=0.001,
        sindy_library_polynomial_degree=2,
        
        save_path_spice=path_spice,
        verbose=True,
    )



print(f"\nStarting training on {estimator.device}...")
print("=" * 80)
estimator.fit(dataset.xs, dataset.ys)
# estimator.load_spice(args.model)
print("=" * 80)
print("\nTraining complete!")

# Print example SPICE model for first participant
print("\nExample SPICE model (participant 0):")
print("-" * 80)
estimator.print_spice_model(participant_id=0)
print("-" * 80)
# Out:
# Starting training on cuda...
# ================================================================================
#
# Training the RNN...
# ================================================================================
# Epoch 1/1000 --- L(Train): 2.5581338 --- Time: 5.63s; --- Convergence: 1.28e+00
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.0 1 + 0.968 visited_self[t] + 0.03 visited_self^2
# visited_partner[t+1] = -0.002 1 + 0.997 visited_partner[t] + -0.002 visited_partner^2
# not_visited[t+1] = -0.001 1 + 1.001 not_visited[t] + -0.001 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 2/1000 --- L(Train): 2.1911652 --- Time: 4.83s; --- Convergence: 8.23e-01
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.004 1 + 0.923 visited_self[t] + 0.048 visited_self^2
# visited_partner[t+1] = 0.002 1 + 0.997 visited_partner[t] + -0.0 visited_partner^2
# not_visited[t+1] = -0.0 1 + 0.995 not_visited[t] + 0.009 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 3/1000 --- L(Train): 2.0089627 --- Time: 4.85s; --- Convergence: 5.03e-01
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.023 1 + 0.851 visited_self[t] + -0.012 visited_self^2
# visited_partner[t+1] = 0.006 1 + 0.999 visited_partner[t] + -0.003 visited_partner^2
# not_visited[t+1] = -0.0 1 + 0.972 not_visited[t] + 0.009 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 4/1000 --- L(Train): 1.8832905 --- Time: 4.79s; --- Convergence: 3.14e-01
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.023 1 + 0.759 visited_self[t] + -0.004 visited_self^2
# visited_partner[t+1] = 0.01 1 + 1.0 visited_partner[t] + -0.023 visited_partner^2
# not_visited[t+1] = -0.001 1 + 0.929 not_visited[t] + 0.021 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 5/1000 --- L(Train): 1.7653696 --- Time: 4.77s; --- Convergence: 2.16e-01
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.02 1 + 0.651 visited_self[t] + 0.001 visited_self^2
# visited_partner[t+1] = 0.018 1 + 0.99 visited_partner[t] + -0.028 visited_partner^2
# not_visited[t+1] = -0.011 1 + 0.87 not_visited[t] + 0.013 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 6/1000 --- L(Train): 1.6582570 --- Time: 5.17s; --- Convergence: 1.62e-01
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.017 1 + 0.538 visited_self[t] + 0.001 visited_self^2
# visited_partner[t+1] = 0.027 1 + 0.978 visited_partner[t] + -0.046 visited_partner^2
# not_visited[t+1] = -0.004 1 + 0.809 not_visited[t] + 0.031 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 7/1000 --- L(Train): 1.6071332 --- Time: 5.29s; --- Convergence: 1.06e-01
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.012 1 + 0.437 visited_self[t] + 0.001 visited_self^2
# visited_partner[t+1] = 0.032 1 + 0.972 visited_partner[t] + -0.07 visited_partner^2
# not_visited[t+1] = 0.023 1 + 0.751 not_visited[t] + 0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 8/1000 --- L(Train): 1.5741378 --- Time: 4.91s; --- Convergence: 6.97e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = -0.002 1 + 0.321 visited_self[t] + 0.008 visited_self^2
# visited_partner[t+1] = 0.023 1 + 0.966 visited_partner[t] + -0.069 visited_partner^2
# not_visited[t+1] = 0.059 1 + 0.678 not_visited[t] + 0.005 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 9/1000 --- L(Train): 1.5248251 --- Time: 4.94s; --- Convergence: 5.95e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.001 1 + 0.215 visited_self[t] + -0.003 visited_self^2
# visited_partner[t+1] = 0.007 1 + 0.96 visited_partner[t] + -0.026 visited_partner^2
# not_visited[t+1] = 0.059 1 + 0.613 not_visited[t] + 0.003 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 10/1000 --- L(Train): 1.5087033 --- Time: 4.92s; --- Convergence: 3.78e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.006 1 + 0.114 visited_self[t] + 0.004 visited_self^2
# visited_partner[t+1] = -0.015 1 + 0.941 visited_partner[t] + -0.024 visited_partner^2
# not_visited[t+1] = 0.053 1 + 0.553 not_visited[t] + 0.001 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 11/1000 --- L(Train): 1.5075966 --- Time: 4.99s; --- Convergence: 1.95e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.011 1 + 0.011 visited_self[t] + 0.002 visited_self^2
# visited_partner[t+1] = -0.034 1 + 0.913 visited_partner[t] + -0.047 visited_partner^2
# not_visited[t+1] = 0.084 1 + 0.494 not_visited[t] + -0.017 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 12/1000 --- L(Train): 1.5179916 --- Time: 4.90s; --- Convergence: 1.49e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.026 1 + -0.108 visited_self[t] + 0.005 visited_self^2
# visited_partner[t+1] = -0.046 1 + 0.878 visited_partner[t] + -0.054 visited_partner^2
# not_visited[t+1] = 0.029 1 + 0.514 not_visited[t] + -0.069 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 13/1000 --- L(Train): 1.5030508 --- Time: 5.00s; --- Convergence: 1.49e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.049 1 + -0.232 visited_self[t] + -0.0 visited_self^2
# visited_partner[t+1] = -0.036 1 + 0.819 visited_partner[t] + -0.043 visited_partner^2
# not_visited[t+1] = -0.112 1 + 0.659 not_visited[t] + -0.06 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 14/1000 --- L(Train): 1.5078141 --- Time: 5.41s; --- Convergence: 9.85e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.076 1 + -0.356 visited_self[t] + -0.008 visited_self^2
# visited_partner[t+1] = -0.02 1 + 0.752 visited_partner[t] + -0.058 visited_partner^2
# not_visited[t+1] = -0.24 1 + 0.795 not_visited[t] + -0.004 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 15/1000 --- L(Train): 1.5078790 --- Time: 5.38s; --- Convergence: 4.96e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.098 1 + -0.456 visited_self[t] + -0.022 visited_self^2
# visited_partner[t+1] = -0.015 1 + 0.715 visited_partner[t] + -0.061 visited_partner^2
# not_visited[t+1] = -0.321 1 + 0.875 not_visited[t] + -0.004 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 16/1000 --- L(Train): 1.4937865 --- Time: 5.14s; --- Convergence: 9.52e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.109 1 + -0.528 visited_self[t] + -0.045 visited_self^2
# visited_partner[t+1] = -0.026 1 + 0.708 visited_partner[t] + -0.053 visited_partner^2
# not_visited[t+1] = -0.349 1 + 0.892 not_visited[t] + 0.008 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 17/1000 --- L(Train): 1.4854528 --- Time: 5.21s; --- Convergence: 8.93e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.138 1 + -0.58 visited_self[t] + -0.021 visited_self^2
# visited_partner[t+1] = -0.052 1 + 0.751 visited_partner[t] + 0.005 visited_partner^2
# not_visited[t+1] = -0.348 1 + 0.873 not_visited[t] + 0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 18/1000 --- L(Train): 1.4927070 --- Time: 4.88s; --- Convergence: 8.09e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.171 1 + -0.603 visited_self[t] + -0.009 visited_self^2
# visited_partner[t+1] = -0.113 1 + 0.848 visited_partner[t] + -0.031 visited_partner^2
# not_visited[t+1] = -0.355 1 + 0.868 not_visited[t] + 0.008 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 19/1000 --- L(Train): 1.4780352 --- Time: 4.93s; --- Convergence: 1.14e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.302 1 + -0.603 visited_self[t] + 0.04 visited_self^2
# visited_partner[t+1] = -0.147 1 + 0.91 visited_partner[t] + -0.06 visited_partner^2
# not_visited[t+1] = -0.366 1 + 0.868 not_visited[t] + -0.001 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 20/1000 --- L(Train): 1.4736857 --- Time: 5.03s; --- Convergence: 7.87e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.458 1 + -0.593 visited_self[t] + 0.11 visited_self^2
# visited_partner[t+1] = -0.128 1 + 0.897 visited_partner[t] + -0.021 visited_partner^2
# not_visited[t+1] = -0.37 1 + 0.858 not_visited[t] + 0.004 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 21/1000 --- L(Train): 1.4850130 --- Time: 5.63s; --- Convergence: 9.60e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.601 1 + -0.579 visited_self[t] + 0.182 visited_self^2
# visited_partner[t+1] = -0.116 1 + 0.891 visited_partner[t] + 0.003 visited_partner^2
# not_visited[t+1] = -0.381 1 + 0.855 not_visited[t] + 0.001 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 22/1000 --- L(Train): 1.4688370 --- Time: 5.39s; --- Convergence: 1.29e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.73 1 + -0.565 visited_self[t] + 0.251 visited_self^2
# visited_partner[t+1] = -0.126 1 + 0.907 visited_partner[t] + -0.009 visited_partner^2
# not_visited[t+1] = -0.388 1 + 0.844 not_visited[t] + 0.004 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 23/1000 --- L(Train): 1.4707005 --- Time: 5.53s; --- Convergence: 7.37e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.823 1 + -0.553 visited_self[t] + 0.302 visited_self^2
# visited_partner[t+1] = -0.132 1 + 0.917 visited_partner[t] + -0.015 visited_partner^2
# not_visited[t+1] = -0.397 1 + 0.837 not_visited[t] + 0.003 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 24/1000 --- L(Train): 1.4728630 --- Time: 5.45s; --- Convergence: 4.77e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.889 1 + -0.544 visited_self[t] + 0.339 visited_self^2
# visited_partner[t+1] = -0.13 1 + 0.914 visited_partner[t] + -0.011 visited_partner^2
# not_visited[t+1] = -0.404 1 + 0.828 not_visited[t] + 0.003 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 25/1000 --- L(Train): 1.4702480 --- Time: 5.28s; --- Convergence: 3.69e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.938 1 + -0.537 visited_self[t] + 0.365 visited_self^2
# visited_partner[t+1] = -0.128 1 + 0.91 visited_partner[t] + -0.008 visited_partner^2
# not_visited[t+1] = -0.409 1 + 0.819 not_visited[t] + 0.003 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 26/1000 --- L(Train): 1.4729660 --- Time: 4.82s; --- Convergence: 3.20e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.973 1 + -0.531 visited_self[t] + 0.385 visited_self^2
# visited_partner[t+1] = -0.131 1 + 0.91 visited_partner[t] + -0.011 visited_partner^2
# not_visited[t+1] = -0.412 1 + 0.811 not_visited[t] + -0.0 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 27/1000 --- L(Train): 1.4659494 --- Time: 4.99s; --- Convergence: 5.11e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.0 1 + -0.526 visited_self[t] + 0.4 visited_self^2
# visited_partner[t+1] = -0.135 1 + 0.91 visited_partner[t] + -0.014 visited_partner^2
# not_visited[t+1] = -0.417 1 + 0.804 not_visited[t] + -0.002 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 28/1000 --- L(Train): 1.4756944 --- Time: 4.90s; --- Convergence: 7.43e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.018 1 + -0.522 visited_self[t] + 0.409 visited_self^2
# visited_partner[t+1] = -0.135 1 + 0.908 visited_partner[t] + -0.014 visited_partner^2
# not_visited[t+1] = -0.423 1 + 0.796 not_visited[t] + -0.003 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 29/1000 --- L(Train): 1.4654934 --- Time: 5.35s; --- Convergence: 8.81e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.03 1 + -0.519 visited_self[t] + 0.416 visited_self^2
# visited_partner[t+1] = -0.137 1 + 0.906 visited_partner[t] + -0.014 visited_partner^2
# not_visited[t+1] = -0.432 1 + 0.789 not_visited[t] + -0.004 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 30/1000 --- L(Train): 1.4793577 --- Time: 5.13s; --- Convergence: 1.13e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.039 1 + -0.515 visited_self[t] + 0.421 visited_self^2
# visited_partner[t+1] = -0.139 1 + 0.902 visited_partner[t] + -0.015 visited_partner^2
# not_visited[t+1] = -0.441 1 + 0.781 not_visited[t] + -0.005 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 31/1000 --- L(Train): 1.4783666 --- Time: 5.61s; --- Convergence: 6.17e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.043 1 + -0.512 visited_self[t] + 0.423 visited_self^2
# visited_partner[t+1] = -0.141 1 + 0.9 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.451 1 + 0.772 not_visited[t] + -0.005 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 32/1000 --- L(Train): 1.4737588 --- Time: 5.38s; --- Convergence: 5.39e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.045 1 + -0.51 visited_self[t] + 0.424 visited_self^2
# visited_partner[t+1] = -0.143 1 + 0.898 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.459 1 + 0.764 not_visited[t] + -0.005 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 33/1000 --- L(Train): 1.4810891 --- Time: 5.27s; --- Convergence: 6.36e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.046 1 + -0.507 visited_self[t] + 0.424 visited_self^2
# visited_partner[t+1] = -0.145 1 + 0.898 visited_partner[t] + -0.017 visited_partner^2
# not_visited[t+1] = -0.468 1 + 0.757 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 34/1000 --- L(Train): 1.4651219 --- Time: 5.29s; --- Convergence: 1.12e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.047 1 + -0.505 visited_self[t] + 0.424 visited_self^2
# visited_partner[t+1] = -0.148 1 + 0.896 visited_partner[t] + -0.018 visited_partner^2
# not_visited[t+1] = -0.477 1 + 0.748 not_visited[t] + -0.007 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 35/1000 --- L(Train): 1.4796613 --- Time: 4.87s; --- Convergence: 1.29e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.047 1 + -0.503 visited_self[t] + 0.423 visited_self^2
# visited_partner[t+1] = -0.149 1 + 0.893 visited_partner[t] + -0.018 visited_partner^2
# not_visited[t+1] = -0.486 1 + 0.74 not_visited[t] + -0.008 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 36/1000 --- L(Train): 1.4718599 --- Time: 4.88s; --- Convergence: 1.03e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.048 1 + -0.501 visited_self[t] + 0.423 visited_self^2
# visited_partner[t+1] = -0.15 1 + 0.892 visited_partner[t] + -0.018 visited_partner^2
# not_visited[t+1] = -0.494 1 + 0.735 not_visited[t] + -0.009 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 37/1000 --- L(Train): 1.4677577 --- Time: 4.98s; --- Convergence: 7.21e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.048 1 + -0.499 visited_self[t] + 0.422 visited_self^2
# visited_partner[t+1] = -0.151 1 + 0.894 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.501 1 + 0.731 not_visited[t] + -0.009 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 38/1000 --- L(Train): 1.4733232 --- Time: 4.90s; --- Convergence: 6.39e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.046 1 + -0.497 visited_self[t] + 0.421 visited_self^2
# visited_partner[t+1] = -0.152 1 + 0.896 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.509 1 + 0.727 not_visited[t] + -0.011 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 39/1000 --- L(Train): 1.4703313 --- Time: 4.83s; --- Convergence: 4.69e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.044 1 + -0.495 visited_self[t] + 0.42 visited_self^2
# visited_partner[t+1] = -0.154 1 + 0.897 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.514 1 + 0.721 not_visited[t] + -0.01 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 40/1000 --- L(Train): 1.4735688 --- Time: 4.79s; --- Convergence: 3.96e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.044 1 + -0.491 visited_self[t] + 0.419 visited_self^2
# visited_partner[t+1] = -0.157 1 + 0.892 visited_partner[t] + -0.017 visited_partner^2
# not_visited[t+1] = -0.526 1 + 0.716 not_visited[t] + -0.013 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 41/1000 --- L(Train): 1.4678304 --- Time: 4.95s; --- Convergence: 4.85e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.044 1 + -0.488 visited_self[t] + 0.417 visited_self^2
# visited_partner[t+1] = -0.16 1 + 0.888 visited_partner[t] + -0.018 visited_partner^2
# not_visited[t+1] = -0.536 1 + 0.71 not_visited[t] + -0.014 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 42/1000 --- L(Train): 1.4675521 --- Time: 4.85s; --- Convergence: 2.56e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.043 1 + -0.484 visited_self[t] + 0.416 visited_self^2
# visited_partner[t+1] = -0.164 1 + 0.886 visited_partner[t] + -0.018 visited_partner^2
# not_visited[t+1] = -0.545 1 + 0.703 not_visited[t] + -0.012 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 43/1000 --- L(Train): 1.4653093 --- Time: 4.83s; --- Convergence: 2.40e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.042 1 + -0.481 visited_self[t] + 0.414 visited_self^2
# visited_partner[t+1] = -0.167 1 + 0.886 visited_partner[t] + -0.018 visited_partner^2
# not_visited[t+1] = -0.556 1 + 0.699 not_visited[t] + -0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 44/1000 --- L(Train): 1.4660131 --- Time: 4.83s; --- Convergence: 1.55e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.042 1 + -0.478 visited_self[t] + 0.413 visited_self^2
# visited_partner[t+1] = -0.169 1 + 0.885 visited_partner[t] + -0.017 visited_partner^2
# not_visited[t+1] = -0.563 1 + 0.695 not_visited[t] + -0.014 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 45/1000 --- L(Train): 1.4660401 --- Time: 4.91s; --- Convergence: 7.90e-04
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.043 1 + -0.474 visited_self[t] + 0.412 visited_self^2
# visited_partner[t+1] = -0.17 1 + 0.885 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.571 1 + 0.693 not_visited[t] + -0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 46/1000 --- L(Train): 1.4621538 --- Time: 4.88s; --- Convergence: 2.34e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.045 1 + -0.472 visited_self[t] + 0.412 visited_self^2
# visited_partner[t+1] = -0.171 1 + 0.887 visited_partner[t] + -0.014 visited_partner^2
# not_visited[t+1] = -0.576 1 + 0.691 not_visited[t] + -0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 47/1000 --- L(Train): 1.4770934 --- Time: 4.93s; --- Convergence: 8.64e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.045 1 + -0.469 visited_self[t] + 0.411 visited_self^2
# visited_partner[t+1] = -0.173 1 + 0.889 visited_partner[t] + -0.015 visited_partner^2
# not_visited[t+1] = -0.581 1 + 0.688 not_visited[t] + -0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 48/1000 --- L(Train): 1.4628088 --- Time: 4.89s; --- Convergence: 1.15e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.044 1 + -0.464 visited_self[t] + 0.409 visited_self^2
# visited_partner[t+1] = -0.176 1 + 0.888 visited_partner[t] + -0.015 visited_partner^2
# not_visited[t+1] = -0.588 1 + 0.682 not_visited[t] + -0.015 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 49/1000 --- L(Train): 1.4643315 --- Time: 4.86s; --- Convergence: 6.49e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.043 1 + -0.46 visited_self[t] + 0.407 visited_self^2
# visited_partner[t+1] = -0.18 1 + 0.884 visited_partner[t] + -0.015 visited_partner^2
# not_visited[t+1] = -0.595 1 + 0.677 not_visited[t] + -0.017 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 50/1000 --- L(Train): 1.4748334 --- Time: 4.86s; --- Convergence: 8.50e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.042 1 + -0.455 visited_self[t] + 0.405 visited_self^2
# visited_partner[t+1] = -0.183 1 + 0.881 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.601 1 + 0.672 not_visited[t] + -0.018 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 51/1000 --- L(Train): 1.4669778 --- Time: 4.96s; --- Convergence: 8.18e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.045 1 + -0.45 visited_self[t] + 0.404 visited_self^2
# visited_partner[t+1] = -0.186 1 + 0.88 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.602 1 + 0.667 not_visited[t] + -0.022 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 52/1000 --- L(Train): 1.4583632 --- Time: 4.88s; --- Convergence: 8.40e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.046 1 + -0.445 visited_self[t] + 0.401 visited_self^2
# visited_partner[t+1] = -0.19 1 + 0.877 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.604 1 + 0.659 not_visited[t] + -0.025 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 53/1000 --- L(Train): 1.4832990 --- Time: 4.84s; --- Convergence: 1.67e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.044 1 + -0.44 visited_self[t] + 0.397 visited_self^2
# visited_partner[t+1] = -0.194 1 + 0.876 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.607 1 + 0.652 not_visited[t] + -0.028 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 54/1000 --- L(Train): 1.4625192 --- Time: 4.88s; --- Convergence: 1.87e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.047 1 + -0.434 visited_self[t] + 0.395 visited_self^2
# visited_partner[t+1] = -0.199 1 + 0.874 visited_partner[t] + -0.017 visited_partner^2
# not_visited[t+1] = -0.612 1 + 0.644 not_visited[t] + -0.032 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 55/1000 --- L(Train): 1.4611015 --- Time: 4.82s; --- Convergence: 1.01e-02
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.048 1 + -0.428 visited_self[t] + 0.392 visited_self^2
# visited_partner[t+1] = -0.204 1 + 0.873 visited_partner[t] + -0.016 visited_partner^2
# not_visited[t+1] = -0.617 1 + 0.638 not_visited[t] + -0.035 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 56/1000 --- L(Train): 1.4581216 --- Time: 4.84s; --- Convergence: 6.53e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.05 1 + -0.423 visited_self[t] + 0.39 visited_self^2
# visited_partner[t+1] = -0.207 1 + 0.875 visited_partner[t] + -0.014 visited_partner^2
# not_visited[t+1] = -0.62 1 + 0.632 not_visited[t] + -0.037 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 57/1000 --- L(Train): 1.4636914 --- Time: 4.96s; --- Convergence: 6.05e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.053 1 + -0.417 visited_self[t] + 0.389 visited_self^2
# visited_partner[t+1] = -0.209 1 + 0.876 visited_partner[t] + -0.011 visited_partner^2
# not_visited[t+1] = -0.623 1 + 0.625 not_visited[t] + -0.038 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 58/1000 --- L(Train): 1.4593752 --- Time: 4.86s; --- Convergence: 5.18e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.057 1 + -0.412 visited_self[t] + 0.388 visited_self^2
# visited_partner[t+1] = -0.212 1 + 0.875 visited_partner[t] + -0.01 visited_partner^2
# not_visited[t+1] = -0.626 1 + 0.621 not_visited[t] + -0.042 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 59/1000 --- L(Train): 1.4651503 --- Time: 4.86s; --- Convergence: 5.48e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.059 1 + -0.407 visited_self[t] + 0.386 visited_self^2
# visited_partner[t+1] = -0.215 1 + 0.877 visited_partner[t] + -0.011 visited_partner^2
# not_visited[t+1] = -0.628 1 + 0.617 not_visited[t] + -0.046 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 60/1000 --- L(Train): 1.4599202 --- Time: 4.85s; --- Convergence: 5.35e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.058 1 + -0.401 visited_self[t] + 0.381 visited_self^2
# visited_partner[t+1] = -0.217 1 + 0.876 visited_partner[t] + -0.008 visited_partner^2
# not_visited[t+1] = -0.629 1 + 0.613 not_visited[t] + -0.046 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 61/1000 --- L(Train): 1.4622066 --- Time: 5.45s; --- Convergence: 3.82e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.062 1 + -0.395 visited_self[t] + 0.379 visited_self^2
# visited_partner[t+1] = -0.219 1 + 0.875 visited_partner[t] + -0.008 visited_partner^2
# not_visited[t+1] = -0.631 1 + 0.611 not_visited[t] + -0.047 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 62/1000 --- L(Train): 1.4539424 --- Time: 5.56s; --- Convergence: 6.04e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.066 1 + -0.389 visited_self[t] + 0.376 visited_self^2
# visited_partner[t+1] = -0.223 1 + 0.872 visited_partner[t] + -0.011 visited_partner^2
# not_visited[t+1] = -0.635 1 + 0.608 not_visited[t] + -0.047 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 63/1000 --- L(Train): 1.4598193 --- Time: 5.58s; --- Convergence: 5.96e-03
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.074 1 + -0.383 visited_self[t] + 0.374 visited_self^2
# visited_partner[t+1] = -0.226 1 + 0.87 visited_partner[t] + -0.011 visited_partner^2
# ...
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 981/1000 --- L(Train): 0.0085454 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 982/1000 --- L(Train): 0.0085507 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 983/1000 --- L(Train): 0.0085556 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 984/1000 --- L(Train): 0.0085512 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 985/1000 --- L(Train): 0.0085450 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 986/1000 --- L(Train): 0.0085529 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 987/1000 --- L(Train): 0.0085548 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 988/1000 --- L(Train): 0.0085539 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 989/1000 --- L(Train): 0.0085516 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 990/1000 --- L(Train): 0.0085495 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 991/1000 --- L(Train): 0.0085505 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 992/1000 --- L(Train): 0.0085511 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 993/1000 --- L(Train): 0.0085511 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 994/1000 --- L(Train): 0.0085512 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 995/1000 --- L(Train): 0.0085520 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 996/1000 --- L(Train): 0.0085526 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 997/1000 --- L(Train): 0.0085541 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 998/1000 --- L(Train): 0.0085581 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 999/1000 --- L(Train): 0.0085631 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 1000/1000 --- L(Train): 0.0085709 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 1001/1000 --- L(Train): 0.0085872 --- L(Val): 0.0000000 --- Time: 0.12s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 6):
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
#
# RNN training finished.
# Training took 757.04 seconds.
# Saving SPICE model to spice_huang2025.pkl...
# ================================================================================
#
# Training complete!
#
# Example SPICE model (participant 0):
# --------------------------------------------------------------------------------
# visited_self[t+1] = 2.694 1 + -0.006 visited_self[t]
# visited_partner[t+1] = -0.263 1 + 0.875 visited_partner[t]
# not_visited[t+1] = -0.672 1 + 0.508 not_visited[t] + -0.083 not_visited^2
# --------------------------------------------------------------------------------

# %%
estimator.print_spice_model(participant_id=1)
# Out:
# visited_self[t+1] = 2.49 1 + -0.046 visited_self[t]
# visited_partner[t+1] = -0.079 1 + 1.0 visited_partner[t]
# not_visited[t+1] = -1.38 1 + 0.018 not_visited[t]

# %%
estimator.rnn_model.sindy_coefficients['visited_self']
