# %%
#!pip install -e SPICE --no-deps

# %%
# !ls ~/SPICE/examples/
# Out:
# ls: cannot access '/home/daniel/SPICE/examples/': No such file or directory

# %%
#!git clone https://github.com/whyhardt/SPICE.git

# %%
#!git clone https://github.com/whyhardt/SPICE.git
# !python --version

import sys
import os

# 1. Get the absolute path to your cloned folder
# Assuming the folder 'SPICE' is in your current working directory
project_root = os.path.abspath("SPICE")

# 2. Check for the likely internal structure
# Many modern packages hide the actual code inside a 'src' folder
if os.path.exists(os.path.join(project_root, "src")):
    package_path = os.path.join(project_root, "src")
else:
    package_path = project_root

if package_path not in sys.path:
    sys.path.append(package_path)
    print(f"✅ Added {package_path} to system path")

# 4. Now try the import
try:
    from spice.estimator import SpiceEstimator
    print("✅ Success! SpiceEstimator imported.")
except ImportError as e:
    print(f"❌ Still failing. Debug info below:")
    print(f"Contents of {package_path}: {os.listdir(package_path)}")
    raise e
# Out:
# Python 3.11.13
# ✅ Added /home/daniel/repositories/SPICE/weinhardt2025/aux/SPICE to system path
# ✅ Success! SpiceEstimator imported.

# %%
import pandas as pd
import numpy as np
from typing import Dict, List, Tuple
import matplotlib.pyplot as plt

from spice.estimator import SpiceEstimator
from spice.resources.spice_utils import SpiceConfig
from spice.utils.convert_dataset import convert_dataset
from spice.resources.rnn import BaseRNN

# For custom RNN
import torch
import torch.nn as nn

# %%
# Load your hover data
dataset = convert_dataset(
    file='../data/huang2025/huang2025.csv',
    df_participant_id = "subject_ID",
    df_block ='currentRound',
    df_choice = 'hover_tile_index',
    df_reward = 'score',
    additional_inputs = ['partner_tile_index', 'sample_number']
    )

# structure of dataset:
# dataset has two main attributes: xs -> inputs; ys -> targets (next action)
# shape: (n_participants*n_blocks*n_experiments, n_timesteps, features)
# features are (n_actions * action, n_actions * reward, n_additional_inputs * additional_input, block_number, experiment_id, participant_id)


# in order to set up the participant embedding we have to compute the number of unique participants in our data 
# to get the number of participants n_participants we do:
n_participants = len(dataset.xs[..., -1].unique())
n_actions = dataset.ys.shape[-1]

# %%
spice_config = SpiceConfig(
    library_setup={
        'visited_self': [],
        'visited_partner': [],
        'not_visited': [],
    },
    
    memory_state={
        'value_tile': 0,
    },
)

# %%
class HoverRNN(BaseRNN):
    """
    Custom RNN for modeling hover behavior.

    CRITICAL: Must match the interface expected by SPICE!
    The RNN should:
    - Take input of shape (batch, seq_len, input_size)
    - Return output of shape (batch, seq_len, output_size)
    - Optionally return hidden states
    """

    def __init__(self, spice_config, n_actions, n_participants, **kwargs):
        super(HoverRNN, self).__init__(
            spice_config=spice_config,
            n_actions=n_actions, 
            n_participants=n_participants, 
            embedding_size=32,
            sindy_polynomial_degree=2,
            )

        dropout = 0.1
        
        self.participant_embedding = self.setup_embedding(n_participants, self.embedding_size, dropout=dropout)
        
        # Value learning module (slow updates)
        # Can use recent reward history to modulate learning
        self.setup_module(key_module='visited_self', input_size=self.embedding_size, dropout=dropout)
        self.setup_module(key_module='visited_partner', input_size=self.embedding_size, dropout=dropout)
        self.setup_module(key_module='not_visited', input_size=self.embedding_size, dropout=dropout)
        
    def forward(self, inputs, prev_state=None, batch_first=False):
        """
        Forward pass.

        Args:
            inputs: Tuple containing (actions, rewards, additional_inputs, participant_ids)
            prev_state: Optional previous hidden state
            batch_first: Whether first dimension is batch (True) or timesteps (False)

        Returns:
            logits: (batch, seq_len, n_actions) - Action logits for each tile
            state: Updated hidden state dictionary
        """

        # Initialize inputs, outputs, and timesteps
        spice_signals = self.init_forward_pass(inputs, prev_state, batch_first)

        nan_mask = spice_signals.actions.isnan()
        tiles_visited_partner = spice_signals.additional_inputs[..., 0].nan_to_num(0).long()
        actions_partner = torch.nn.functional.one_hot(tiles_visited_partner, num_classes=self.n_actions)
        actions_partner = torch.where(nan_mask, torch.nan, actions_partner)
        actions_not_visited = 1 - (spice_signals.actions + actions_partner)
        
        # Get participant embeddings
        participant_embedding = self.participant_embedding(spice_signals.participant_ids)
        
        # Main loop: process each timestep
        for timestep in spice_signals.timesteps:
            
            # Update value for tile visited by self
            self.call_module(
                key_module='visited_self',
                key_state='value_tile',
                action_mask=spice_signals.actions[timestep],
                inputs=None,
                participant_embedding=participant_embedding,
                participant_index=spice_signals.participant_ids,
            )
            
            # Update value for tile visited by partner
            self.call_module(
                key_module='visited_partner',
                key_state='value_tile',
                action_mask=actions_partner[timestep],
                inputs=None,
                participant_embedding=participant_embedding,
                participant_index=spice_signals.participant_ids,
            )
            
            self.call_module(
                key_module='not_visited',
                key_state='value_tile',
                action_mask=actions_not_visited[timestep],
                inputs=None,
                participant_embedding=participant_embedding,
                participant_index=spice_signals.participant_ids,
            )
            
            # Apply beta parameters for each tile and compute logits
            spice_signals.logits[timestep] = self.state['value_tile']
        
        # Post-process the forward pass
        spice_signals = self.post_forward_pass(spice_signals, batch_first)

        return spice_signals.logits, self.get_state()

# %%
path_spice = 'spice_huang2025.pkl'

estimator = SpiceEstimator(
        device = torch.device("cuda"),
        # SPICE parameters
        rnn_class=HoverRNN,
        spice_config=spice_config,
        n_actions=n_actions,
        n_participants=n_participants,
        
        # rnn training parameters
        epochs=1000, # better: 4000 or 5000
        warmup_steps=1000,
        learning_rate=0.01,
        batch_size=512,
        bagging=True
        
        # sindy fitting parameters
        sindy_weight=1,
        sindy_threshold=0.05,
        sindy_threshold_frequency=1,
        sindy_threshold_terms=1,
        sindy_cutoff_patience=100,
        sindy_epochs=1000,
        sindy_alpha=0.001,
        sindy_library_polynomial_degree=2,
        
        save_path_spice=path_spice,
    )



print(f"\nStarting training on {estimator.device}...")
print("=" * 80)
estimator.fit(dataset.xs, dataset.ys)
# estimator.load_spice(args.model)
print("=" * 80)
print("\nTraining complete!")

# Print example SPICE model for first participant
print("\nExample SPICE model (participant 0):")
print("-" * 80)
estimator.print_spice_model(participant_id=0)
print("-" * 80)
# Out:
# Starting training on cuda...
# ================================================================================
#
# Training the RNN...
#
# ================================================================================
# Starting second stage SINDy fitting (threshold=0.05, single model)
# ================================================================================
# ================================================================================
# Epoch 1/1000 --- L(Train): 0.4788740 --- L(Val): 0.0000000 --- Time: 0.13s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.102 1 + 0.9 visited_self[t] + 0.101 visited_self^2
# visited_partner[t+1] = -0.099 1 + 1.1 visited_partner[t] + -0.099 visited_partner^2
# not_visited[t+1] = -0.101 1 + 0.899 not_visited[t] + -0.1 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 2/1000 --- L(Train): 0.4259432 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.189 1 + 0.801 visited_self[t] + 0.183 visited_self^2
# visited_partner[t+1] = -0.035 1 + 1.03 visited_partner[t] + -0.031 visited_partner^2
# not_visited[t+1] = -0.045 1 + 0.816 not_visited[t] + -0.034 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 3/1000 --- L(Train): 0.3190205 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.242 1 + 0.701 visited_self[t] + 0.217 visited_self^2
# visited_partner[t+1] = 0.027 1 + 0.961 visited_partner[t] + 0.035 visited_partner^2
# not_visited[t+1] = -0.059 1 + 0.788 not_visited[t] + -0.036 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 4/1000 --- L(Train): 0.2938965 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.267 1 + 0.601 visited_self[t] + 0.217 visited_self^2
# visited_partner[t+1] = 0.044 1 + 0.933 visited_partner[t] + 0.057 visited_partner^2
# not_visited[t+1] = -0.105 1 + 0.795 not_visited[t] + -0.072 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 5/1000 --- L(Train): 0.2307504 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.284 1 + 0.503 visited_self[t] + 0.207 visited_self^2
# visited_partner[t+1] = 0.024 1 + 0.941 visited_partner[t] + 0.042 visited_partner^2
# not_visited[t+1] = -0.152 1 + 0.8 not_visited[t] + -0.108 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 6/1000 --- L(Train): 0.2056525 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.311 1 + 0.409 visited_self[t] + 0.208 visited_self^2
# visited_partner[t+1] = -0.013 1 + 0.968 visited_partner[t] + 0.009 visited_partner^2
# not_visited[t+1] = -0.178 1 + 0.781 not_visited[t] + -0.121 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 7/1000 --- L(Train): 0.1802447 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.354 1 + 0.322 visited_self[t] + 0.227 visited_self^2
# visited_partner[t+1] = -0.053 1 + 1.0 visited_partner[t] + -0.028 visited_partner^2
# not_visited[t+1] = -0.182 1 + 0.743 not_visited[t] + -0.111 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 8/1000 --- L(Train): 0.1373449 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.409 1 + 0.243 visited_self[t] + 0.261 visited_self^2
# visited_partner[t+1] = -0.083 1 + 1.023 visited_partner[t] + -0.054 visited_partner^2
# not_visited[t+1] = -0.18 1 + 0.699 not_visited[t] + -0.095 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 9/1000 --- L(Train): 0.1180046 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.469 1 + 0.171 visited_self[t] + 0.303 visited_self^2
# visited_partner[t+1] = -0.097 1 + 1.029 visited_partner[t] + -0.063 visited_partner^2
# not_visited[t+1] = -0.187 1 + 0.661 not_visited[t] + -0.088 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 10/1000 --- L(Train): 0.1149610 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.529 1 + 0.104 visited_self[t] + 0.344 visited_self^2
# visited_partner[t+1] = -0.093 1 + 1.018 visited_partner[t] + -0.055 visited_partner^2
# not_visited[t+1] = -0.211 1 + 0.64 not_visited[t] + -0.097 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 11/1000 --- L(Train): 0.0967022 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.581 1 + 0.04 visited_self[t] + 0.376 visited_self^2
# visited_partner[t+1] = -0.079 1 + 0.996 visited_partner[t] + -0.036 visited_partner^2
# not_visited[t+1] = -0.245 1 + 0.629 not_visited[t] + -0.118 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 12/1000 --- L(Train): 0.0753006 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.62 1 + -0.022 visited_self[t] + 0.393 visited_self^2
# visited_partner[t+1] = -0.06 1 + 0.97 visited_partner[t] + -0.012 visited_partner^2
# not_visited[t+1] = -0.283 1 + 0.621 not_visited[t] + -0.142 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 13/1000 --- L(Train): 0.0714362 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.646 1 + -0.081 visited_self[t] + 0.397 visited_self^2
# visited_partner[t+1] = -0.046 1 + 0.947 visited_partner[t] + 0.008 visited_partner^2
# not_visited[t+1] = -0.313 1 + 0.605 not_visited[t] + -0.157 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 14/1000 --- L(Train): 0.0738124 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.665 1 + -0.135 visited_self[t] + 0.393 visited_self^2
# visited_partner[t+1] = -0.04 1 + 0.933 visited_partner[t] + 0.018 visited_partner^2
# not_visited[t+1] = -0.332 1 + 0.578 not_visited[t] + -0.16 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 15/1000 --- L(Train): 0.0675147 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.682 1 + -0.181 visited_self[t] + 0.387 visited_self^2
# visited_partner[t+1] = -0.046 1 + 0.93 visited_partner[t] + 0.016 visited_partner^2
# not_visited[t+1] = -0.342 1 + 0.543 not_visited[t] + -0.155 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 16/1000 --- L(Train): 0.0608749 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.702 1 + -0.216 visited_self[t] + 0.385 visited_self^2
# visited_partner[t+1] = -0.061 1 + 0.937 visited_partner[t] + 0.004 visited_partner^2
# not_visited[t+1] = -0.352 1 + 0.507 not_visited[t] + -0.148 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 17/1000 --- L(Train): 0.0612244 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.728 1 + -0.239 visited_self[t] + 0.391 visited_self^2
# visited_partner[t+1] = -0.081 1 + 0.949 visited_partner[t] + -0.014 visited_partner^2
# not_visited[t+1] = -0.368 1 + 0.477 not_visited[t] + -0.148 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 18/1000 --- L(Train): 0.0607516 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.758 1 + -0.252 visited_self[t] + 0.402 visited_self^2
# visited_partner[t+1] = -0.101 1 + 0.962 visited_partner[t] + -0.032 visited_partner^2
# not_visited[t+1] = -0.393 1 + 0.457 not_visited[t] + -0.156 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 19/1000 --- L(Train): 0.0560969 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.79 1 + -0.257 visited_self[t] + 0.415 visited_self^2
# visited_partner[t+1] = -0.117 1 + 0.969 visited_partner[t] + -0.045 visited_partner^2
# not_visited[t+1] = -0.424 1 + 0.444 not_visited[t] + -0.172 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 20/1000 --- L(Train): 0.0540574 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.818 1 + -0.255 visited_self[t] + 0.424 visited_self^2
# visited_partner[t+1] = -0.124 1 + 0.968 visited_partner[t] + -0.051 visited_partner^2
# not_visited[t+1] = -0.456 1 + 0.431 not_visited[t] + -0.188 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 21/1000 --- L(Train): 0.0552712 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.837 1 + -0.251 visited_self[t] + 0.425 visited_self^2
# visited_partner[t+1] = -0.122 1 + 0.959 visited_partner[t] + -0.048 visited_partner^2
# not_visited[t+1] = -0.484 1 + 0.414 not_visited[t] + -0.198 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 22/1000 --- L(Train): 0.0532849 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.848 1 + -0.244 visited_self[t] + 0.416 visited_self^2
# visited_partner[t+1] = -0.115 1 + 0.943 visited_partner[t] + -0.04 visited_partner^2
# not_visited[t+1] = -0.503 1 + 0.389 not_visited[t] + -0.201 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 23/1000 --- L(Train): 0.0481901 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.851 1 + -0.235 visited_self[t] + 0.4 visited_self^2
# visited_partner[t+1] = -0.104 1 + 0.925 visited_partner[t] + -0.028 visited_partner^2
# not_visited[t+1] = -0.517 1 + 0.36 not_visited[t] + -0.197 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 24/1000 --- L(Train): 0.0454303 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.85 1 + -0.222 visited_self[t] + 0.38 visited_self^2
# visited_partner[t+1] = -0.096 1 + 0.908 visited_partner[t] + -0.019 visited_partner^2
# not_visited[t+1] = -0.531 1 + 0.331 not_visited[t] + -0.193 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 25/1000 --- L(Train): 0.0449438 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.849 1 + -0.206 visited_self[t] + 0.361 visited_self^2
# visited_partner[t+1] = -0.091 1 + 0.896 visited_partner[t] + -0.013 visited_partner^2
# not_visited[t+1] = -0.55 1 + 0.308 not_visited[t] + -0.194 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 26/1000 --- L(Train): 0.0428375 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.853 1 + -0.185 visited_self[t] + 0.346 visited_self^2
# visited_partner[t+1] = -0.093 1 + 0.89 visited_partner[t] + -0.015 visited_partner^2
# not_visited[t+1] = -0.575 1 + 0.291 not_visited[t] + -0.201 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 27/1000 --- L(Train): 0.0393737 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.861 1 + -0.159 visited_self[t] + 0.337 visited_self^2
# visited_partner[t+1] = -0.101 1 + 0.892 visited_partner[t] + -0.021 visited_partner^2
# not_visited[t+1] = -0.603 1 + 0.279 not_visited[t] + -0.213 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 28/1000 --- L(Train): 0.0371279 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.874 1 + -0.131 visited_self[t] + 0.332 visited_self^2
# visited_partner[t+1] = -0.113 1 + 0.897 visited_partner[t] + -0.032 visited_partner^2
# not_visited[t+1] = -0.631 1 + 0.267 not_visited[t] + -0.223 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 29/1000 --- L(Train): 0.0357303 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.888 1 + -0.101 visited_self[t] + 0.329 visited_self^2
# visited_partner[t+1] = -0.125 1 + 0.903 visited_partner[t] + -0.042 visited_partner^2
# not_visited[t+1] = -0.654 1 + 0.251 not_visited[t] + -0.228 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 30/1000 --- L(Train): 0.0338472 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.899 1 + -0.072 visited_self[t] + 0.323 visited_self^2
# visited_partner[t+1] = -0.135 1 + 0.908 visited_partner[t] + -0.05 visited_partner^2
# not_visited[t+1] = -0.672 1 + 0.231 not_visited[t] + -0.228 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 31/1000 --- L(Train): 0.0322668 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.907 1 + -0.046 visited_self[t] + 0.312 visited_self^2
# visited_partner[t+1] = -0.14 1 + 0.908 visited_partner[t] + -0.053 visited_partner^2
# not_visited[t+1] = -0.687 1 + 0.208 not_visited[t] + -0.224 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 32/1000 --- L(Train): 0.0315942 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.91 1 + -0.024 visited_self[t] + 0.297 visited_self^2
# visited_partner[t+1] = -0.141 1 + 0.903 visited_partner[t] + -0.05 visited_partner^2
# not_visited[t+1] = -0.703 1 + 0.188 not_visited[t] + -0.221 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 33/1000 --- L(Train): 0.0307010 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.911 1 + -0.004 visited_self[t] + 0.279 visited_self^2
# visited_partner[t+1] = -0.137 1 + 0.896 visited_partner[t] + -0.043 visited_partner^2
# not_visited[t+1] = -0.723 1 + 0.172 not_visited[t] + -0.223 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 34/1000 --- L(Train): 0.0293001 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.913 1 + 0.014 visited_self[t] + 0.261 visited_self^2
# visited_partner[t+1] = -0.132 1 + 0.888 visited_partner[t] + -0.035 visited_partner^2
# not_visited[t+1] = -0.748 1 + 0.162 not_visited[t] + -0.229 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 35/1000 --- L(Train): 0.0285540 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.919 1 + 0.03 visited_self[t] + 0.247 visited_self^2
# visited_partner[t+1] = -0.129 1 + 0.881 visited_partner[t] + -0.028 visited_partner^2
# not_visited[t+1] = -0.773 1 + 0.153 not_visited[t] + -0.236 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 36/1000 --- L(Train): 0.0285009 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.93 1 + 0.046 visited_self[t] + 0.239 visited_self^2
# visited_partner[t+1] = -0.129 1 + 0.879 visited_partner[t] + -0.024 visited_partner^2
# not_visited[t+1] = -0.796 1 + 0.143 not_visited[t] + -0.24 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 37/1000 --- L(Train): 0.0280724 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.945 1 + 0.06 visited_self[t] + 0.235 visited_self^2
# visited_partner[t+1] = -0.133 1 + 0.882 visited_partner[t] + -0.023 visited_partner^2
# not_visited[t+1] = -0.814 1 + 0.13 not_visited[t] + -0.24 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 38/1000 --- L(Train): 0.0272854 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.963 1 + 0.073 visited_self[t] + 0.233 visited_self^2
# visited_partner[t+1] = -0.141 1 + 0.889 visited_partner[t] + -0.026 visited_partner^2
# not_visited[t+1] = -0.829 1 + 0.114 not_visited[t] + -0.236 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 39/1000 --- L(Train): 0.0267736 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.981 1 + 0.081 visited_self[t] + 0.231 visited_self^2
# visited_partner[t+1] = -0.151 1 + 0.897 visited_partner[t] + -0.031 visited_partner^2
# not_visited[t+1] = -0.844 1 + 0.099 not_visited[t] + -0.233 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 40/1000 --- L(Train): 0.0263302 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 0.997 1 + 0.086 visited_self[t] + 0.227 visited_self^2
# visited_partner[t+1] = -0.16 1 + 0.906 visited_partner[t] + -0.034 visited_partner^2
# not_visited[t+1] = -0.862 1 + 0.088 not_visited[t] + -0.231 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 41/1000 --- L(Train): 0.0256751 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.011 1 + 0.087 visited_self[t] + 0.22 visited_self^2
# visited_partner[t+1] = -0.167 1 + 0.912 visited_partner[t] + -0.035 visited_partner^2
# not_visited[t+1] = -0.883 1 + 0.081 not_visited[t] + -0.233 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 42/1000 --- L(Train): 0.0250606 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.024 1 + 0.084 visited_self[t] + 0.212 visited_self^2
# visited_partner[t+1] = -0.17 1 + 0.915 visited_partner[t] + -0.032 visited_partner^2
# not_visited[t+1] = -0.905 1 + 0.076 not_visited[t] + -0.237 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 43/1000 --- L(Train): 0.0244412 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.038 1 + 0.079 visited_self[t] + 0.204 visited_self^2
# visited_partner[t+1] = -0.17 1 + 0.915 visited_partner[t] + -0.026 visited_partner^2
# not_visited[t+1] = -0.925 1 + 0.07 not_visited[t] + -0.239 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 44/1000 --- L(Train): 0.0236049 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.055 1 + 0.073 visited_self[t] + 0.199 visited_self^2
# visited_partner[t+1] = -0.17 1 + 0.914 visited_partner[t] + -0.019 visited_partner^2
# not_visited[t+1] = -0.942 1 + 0.062 not_visited[t] + -0.237 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 45/1000 --- L(Train): 0.0228048 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.075 1 + 0.067 visited_self[t] + 0.198 visited_self^2
# visited_partner[t+1] = -0.169 1 + 0.913 visited_partner[t] + -0.012 visited_partner^2
# not_visited[t+1] = -0.956 1 + 0.053 not_visited[t] + -0.233 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 46/1000 --- L(Train): 0.0222108 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.097 1 + 0.06 visited_self[t] + 0.2 visited_self^2
# visited_partner[t+1] = -0.171 1 + 0.915 visited_partner[t] + -0.007 visited_partner^2
# not_visited[t+1] = -0.97 1 + 0.043 not_visited[t] + -0.228 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 47/1000 --- L(Train): 0.0215861 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.12 1 + 0.052 visited_self[t] + 0.202 visited_self^2
# visited_partner[t+1] = -0.176 1 + 0.919 visited_partner[t] + -0.005 visited_partner^2
# not_visited[t+1] = -0.986 1 + 0.037 not_visited[t] + -0.226 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 48/1000 --- L(Train): 0.0208816 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.141 1 + 0.044 visited_self[t] + 0.203 visited_self^2
# visited_partner[t+1] = -0.184 1 + 0.926 visited_partner[t] + -0.005 visited_partner^2
# not_visited[t+1] = -1.004 1 + 0.034 not_visited[t] + -0.225 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 49/1000 --- L(Train): 0.0202783 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.16 1 + 0.034 visited_self[t] + 0.202 visited_self^2
# visited_partner[t+1] = -0.193 1 + 0.934 visited_partner[t] + -0.007 visited_partner^2
# not_visited[t+1] = -1.023 1 + 0.032 not_visited[t] + -0.226 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 50/1000 --- L(Train): 0.0197694 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.178 1 + 0.023 visited_self[t] + 0.199 visited_self^2
# visited_partner[t+1] = -0.202 1 + 0.941 visited_partner[t] + -0.008 visited_partner^2
# not_visited[t+1] = -1.041 1 + 0.03 not_visited[t] + -0.225 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 51/1000 --- L(Train): 0.0192825 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.194 1 + 0.013 visited_self[t] + 0.195 visited_self^2
# visited_partner[t+1] = -0.209 1 + 0.945 visited_partner[t] + -0.007 visited_partner^2
# not_visited[t+1] = -1.056 1 + 0.025 not_visited[t] + -0.222 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 52/1000 --- L(Train): 0.0188556 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.21 1 + 0.004 visited_self[t] + 0.192 visited_self^2
# visited_partner[t+1] = -0.213 1 + 0.948 visited_partner[t] + -0.004 visited_partner^2
# not_visited[t+1] = -1.069 1 + 0.02 not_visited[t] + -0.217 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 53/1000 --- L(Train): 0.0184714 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.228 1 + -0.004 visited_self[t] + 0.19 visited_self^2
# visited_partner[t+1] = -0.216 1 + 0.947 visited_partner[t] + 0.001 visited_partner^2
# not_visited[t+1] = -1.082 1 + 0.016 not_visited[t] + -0.212 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 54/1000 --- L(Train): 0.0180835 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.247 1 + -0.01 visited_self[t] + 0.191 visited_self^2
# visited_partner[t+1] = -0.219 1 + 0.946 visited_partner[t] + 0.006 visited_partner^2
# not_visited[t+1] = -1.096 1 + 0.014 not_visited[t] + -0.209 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 55/1000 --- L(Train): 0.0177409 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.265 1 + -0.015 visited_self[t] + 0.191 visited_self^2
# visited_partner[t+1] = -0.222 1 + 0.946 visited_partner[t] + 0.009 visited_partner^2
# not_visited[t+1] = -1.113 1 + 0.014 not_visited[t] + -0.207 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 56/1000 --- L(Train): 0.0174520 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.282 1 + -0.018 visited_self[t] + 0.191 visited_self^2
# visited_partner[t+1] = -0.227 1 + 0.946 visited_partner[t] + 0.01 visited_partner^2
# not_visited[t+1] = -1.129 1 + 0.014 not_visited[t] + -0.206 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 57/1000 --- L(Train): 0.0171388 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.297 1 + -0.021 visited_self[t] + 0.188 visited_self^2
# visited_partner[t+1] = -0.233 1 + 0.946 visited_partner[t] + 0.009 visited_partner^2
# not_visited[t+1] = -1.143 1 + 0.014 not_visited[t] + -0.203 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 58/1000 --- L(Train): 0.0168005 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.31 1 + -0.023 visited_self[t] + 0.184 visited_self^2
# visited_partner[t+1] = -0.239 1 + 0.947 visited_partner[t] + 0.007 visited_partner^2
# not_visited[t+1] = -1.156 1 + 0.012 not_visited[t] + -0.198 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 59/1000 --- L(Train): 0.0164850 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.321 1 + -0.024 visited_self[t] + 0.179 visited_self^2
# visited_partner[t+1] = -0.245 1 + 0.947 visited_partner[t] + 0.005 visited_partner^2
# not_visited[t+1] = -1.167 1 + 0.01 not_visited[t] + -0.193 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 60/1000 --- L(Train): 0.0161802 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.332 1 + -0.023 visited_self[t] + 0.174 visited_self^2
# visited_partner[t+1] = -0.25 1 + 0.946 visited_partner[t] + 0.003 visited_partner^2
# not_visited[t+1] = -1.18 1 + 0.009 not_visited[t] + -0.188 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 61/1000 --- L(Train): 0.0158683 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.344 1 + -0.021 visited_self[t] + 0.17 visited_self^2
# visited_partner[t+1] = -0.253 1 + 0.942 visited_partner[t] + 0.003 visited_partner^2
# not_visited[t+1] = -1.193 1 + 0.01 not_visited[t] + -0.185 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 62/1000 --- L(Train): 0.0155606 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.357 1 + -0.018 visited_self[t] + 0.168 visited_self^2
# visited_partner[t+1] = -0.255 1 + 0.937 visited_partner[t] + 0.004 visited_partner^2
# not_visited[t+1] = -1.208 1 + 0.012 not_visited[t] + -0.183 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 63/1000 --- L(Train): 0.0152558 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.369 1 + -0.014 visited_self[t] + 0.165 visited_self^2
# visited_partner[t+1] = -0.256 1 + 0.931 visited_partner[t] + 0.005 visited_partner^2
# not_visited[t+1] = -1.221 1 + 0.014 not_visited[t] + -0.18 not_visited^2
# ...
# not_visited[t+1] = -1.784 1 + 0.033 not_visited[t] + -0.007 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 178/1000 --- L(Train): 0.0086357 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.878 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.36 1 + 0.87 visited_partner[t] + -0.0 visited_partner^2
# not_visited[t+1] = -1.785 1 + 0.033 not_visited[t] + -0.007 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 179/1000 --- L(Train): 0.0086323 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.879 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.361 1 + 0.871 visited_partner[t] + -0.001 visited_partner^2
# not_visited[t+1] = -1.786 1 + 0.033 not_visited[t] + -0.007 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 180/1000 --- L(Train): 0.0086306 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.879 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.362 1 + 0.872 visited_partner[t] + -0.001 visited_partner^2
# not_visited[t+1] = -1.786 1 + 0.033 not_visited[t] + -0.007 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 181/1000 --- L(Train): 0.0086271 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.88 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.363 1 + 0.873 visited_partner[t] + 0.0 visited_partner^2
# not_visited[t+1] = -1.787 1 + 0.033 not_visited[t] + -0.007 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 182/1000 --- L(Train): 0.0086247 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.88 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.363 1 + 0.873 visited_partner[t] + 0.0 visited_partner^2
# not_visited[t+1] = -1.787 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 183/1000 --- L(Train): 0.0086226 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.88 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.363 1 + 0.873 visited_partner[t] + -0.001 visited_partner^2
# not_visited[t+1] = -1.788 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 184/1000 --- L(Train): 0.0086196 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.88 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.363 1 + 0.872 visited_partner[t] + -0.0 visited_partner^2
# not_visited[t+1] = -1.788 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 185/1000 --- L(Train): 0.0086170 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.881 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.362 1 + 0.871 visited_partner[t] + 0.001 visited_partner^2
# not_visited[t+1] = -1.789 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 186/1000 --- L(Train): 0.0086148 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.881 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.362 1 + 0.871 visited_partner[t] + 0.0 visited_partner^2
# not_visited[t+1] = -1.789 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 187/1000 --- L(Train): 0.0086126 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.881 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.362 1 + 0.871 visited_partner[t] + -0.002 visited_partner^2
# not_visited[t+1] = -1.79 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 188/1000 --- L(Train): 0.0086109 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.882 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.362 1 + 0.87 visited_partner[t] + -0.002 visited_partner^2
# not_visited[t+1] = -1.79 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 189/1000 --- L(Train): 0.0086098 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.882 1 + 0.021 visited_self[t] + 0.022 visited_self^2
# visited_partner[t+1] = -0.361 1 + 0.869 visited_partner[t] + -0.001 visited_partner^2
# not_visited[t+1] = -1.79 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 190/1000 --- L(Train): 0.0086061 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.882 1 + 0.021 visited_self[t] + 0.021 visited_self^2
# visited_partner[t+1] = -0.36 1 + 0.868 visited_partner[t] + -0.0 visited_partner^2
# not_visited[t+1] = -1.791 1 + 0.033 not_visited[t] + -0.006 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ================================================================================
# Epoch 191/1000 --- L(Train): 0.0086050 --- L(Val): 0.0000000 --- Time: 0.09s;
# --------------------------------------------------------------------------------
# SPICE Model (Coefficients: 9):
# visited_self[t+1] = 1.882 1 + 0.021 visited_self[t] + 0.021 visited_self^2
# visited_partner[t+1] = -0.36 1 + 0.868 visited_partner[t] + 0.001 visited_partner^2
# not_visited[t+1] = -1.791 1 + 0.033 not_visited[t] + -0.005 not_visited^2
# --------------------------------------------------------------------------------
# Cutoff patience:
# visited_self: [0, 0, 0]
# visited_partner: [0, 0, 0]
# not_visited: [0, 0, 0]
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 35
#      33 print(f"\nStarting training on {estimator.device}...")
#      34 print("=" * 80)
# ---> 35 estimator.fit(dataset.xs, dataset.ys)
#      36 # estimator.load_spice(args.model)
#      37 print("=" * 80)
#
# File ~/repositories/SPICE/spice/estimator.py:204, in SpiceEstimator.fit(self, data, targets, data_test, target_test)
#     200 print('\nTraining the RNN...')
#     202 batch_size = data.shape[0] if self.batch_size is None else self.batch_size
# --> 204 rnn_model, rnn_optimizer, _ = fit_model(
#     205     model=self.rnn_model,
#     206     dataset_train=dataset,
#     207     dataset_test=dataset_test,
#     208     optimizer=self.rnn_optimizer,
#     209     convergence_threshold=self.convergence_threshold,
#     210     sindy_weight=self.sindy_weight,
#     211     sindy_alpha=self.sindy_alpha,
#     212     sindy_threshold=self.sindy_threshold,
#     213     sindy_threshold_frequency=self.sindy_threshold_frequency,
#     214     sindy_threshold_terms=self.sindy_threshold_terms,
#     215     sindy_threshold_patience=self.sindy_cutoff_patience,
#     216     sindy_epochs=self.sindy_epochs,
#     217     epochs=self.epochs,
#     218     n_warmup_steps=self.warmup_steps,
#     219     batch_size=batch_size,
#     220     bagging=self.bagging,
#     221     scheduler=self.scheduler,
#     222     n_steps=self.n_steps_per_call,
#     223     verbose=self.verbose,
#     224     path_save_checkpoints=None,
#     225 )
#     227 self.rnn_model = rnn_model
#     228 self.rnn_optimizer = rnn_optimizer
#
# File ~/repositories/SPICE/spice/resources/spice_training.py:616, in fit_model(model, dataset_train, dataset_test, optimizer, convergence_threshold, sindy_weight, sindy_alpha, sindy_epochs, sindy_threshold, sindy_threshold_frequency, sindy_threshold_terms, sindy_threshold_patience, epochs, batch_size, bagging, scheduler, n_steps, verbose, n_warmup_steps, path_save_checkpoints)
#     614 # Second stage: Refit SINDy coefficients on trained RNN hidden states (always run when sindy_weight > 0)
#     615 if sindy_weight > 0 and sindy_epochs > 0:
# --> 616     model = fit_sindy_second_stage(
#     617         model=model,
#     618         dataset_train=dataset_train,
#     619         dataset_test=dataset_test,
#     620         learning_rate=optimizer.param_groups[0]['lr']*10,
#     621         epochs=sindy_epochs,
#     622         cutoff_threshold=sindy_threshold,
#     623         cutoff_n_terms=sindy_threshold_terms,
#     624         cutoff_patience=sindy_threshold_patience,
#     625         cutoff_warmup=400,#n_warmup_steps,
#     626         sindy_alpha=sindy_alpha,
#     627         batch_size=None,
#     628         verbose=verbose,
#     629     )
#     631 return model.eval(), optimizer, loss_train
#
# File ~/repositories/SPICE/spice/resources/spice_training.py:385, in fit_sindy_second_stage(model, dataset_train, dataset_test, learning_rate, epochs, cutoff_threshold, cutoff_frequency, cutoff_n_terms, cutoff_patience, cutoff_warmup, sindy_alpha, batch_size, verbose)
#     382     batched_target_state_buffer[state] = target_state_buffer_train[state][idx:idx+batch_size][batched_nan_mask]
#     384 # get sindy-based state updates from original rnn states
# --> 385 _, state_pred = model(xs[idx:idx+batch_size, :1].to(model.device)[batched_nan_mask], batched_input_state_buffer, batch_first=True)
#     387 loss_batch = 0
#     388 for state in model.spice_config.states_in_logit:
#
# File ~/miniconda3/envs/spice/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/spice/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[8], line 90, in HoverRNN.forward(self, inputs, prev_state, batch_first)
#      80     self.call_module(
#      81         key_module='not_visited',
#      82         key_state='value_tile',
#    (...)     86         participant_index=spice_signals.participant_ids,
#      87     )
#      89     # Apply beta parameters for each tile and compute logits
# ---> 90     spice_signals.logits[timestep] = self.state['value_tile']
#      92 # Post-process the forward pass
#      93 spice_signals = self.post_forward_pass(spice_signals, batch_first)
#
# KeyboardInterrupt:

# %%
estimator.print_spice_model(participant_id=1)

# %%
estimator.rnn_model.sindy_coefficients['visited_self']
