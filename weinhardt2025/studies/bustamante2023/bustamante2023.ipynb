# %%
#!git clone https://github.com/whyhardt/SPICE.git

# %%
# !pip install -e SPICE

# %%
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from typing import Optional

from spice import SpiceEstimator, SpiceConfig, csv_to_dataset, BaseRNN, plot_session, split_data_along_sessiondim

sys.path.append('../../..')
from weinhardt2026.utils.benchmarking_gru import training
from weinhardt2026.studies.bustamante2023.benchmarking_bustamante2023 import MarginalValueTheoremModel

# For custom RNN
import torch

# %% [markdown]
# ## Load dataset

# %% [markdown]
# Let's load the data first with the `csv_to_dataset` method. This method returns a `SpiceDataset` object which we can use right away

# %%
# Load your data
path_data = 'data/bustamante2023_processed.csv'
dataset = csv_to_dataset(
    file = path_data,
    df_participant_id='subject_id',
    df_choice='decision',
    df_feedback='reward',
    df_block='overall_round',
    additional_inputs=['harvest_duration', 'travel_duration'],
    )

# structure of dataset:
# dataset has two main attributes: xs -> inputs; ys -> targets (next action)
# shape: (n_participants*n_blocks*n_experiments, n_trials, n_timesteps=1, features)
# features are (n_actions * action, n_actions * reward, n_additional_inputs * additional_input, timestep, trial, block, experiment, participant)

# in order to set up the participant embedding we have to compute the number of unique participants in our data 
# to get the number of participants n_participants we do:
n_participants = len(dataset.xs[..., -1].unique())
n_actions = dataset.ys.shape[-1]

print(f"Shape of dataset: {dataset.xs.shape}")
print(f"Number of participants: {n_participants}")
print(f"Number of actions in dataset: {n_actions}")
print(f"Number of additional inputs: {dataset.xs.shape[-1]-2*n_actions-3}")
# Out:
# Shape of dataset: torch.Size([1997, 112, 1, 11])
# Number of participants: 250
# Number of actions in dataset: 2
# Number of additional inputs: 4

# %%
test_sessions = (3, 6)
dataset_train, dataset_test = split_data_along_sessiondim(dataset, test_sessions)

# %% [markdown]
# ## SPICE Setup

# %% [markdown]
# Now we are going to define the configuration for SPICE with a `SpiceConfig` object.
#
# The `SpiceConfig` takes as arguments
# 1. `library_setup (dict)`: Defining the variable names of each module.
# 2. `memory_state (dict)`: Defining the memory state variables and their initial values.
# 3. `states_in_logit (list)`: Defining which of the memory state variables are used later for the logit computation. This is necessary for some background processes.

# %% [markdown]
# And then we are going to define the SPICE model which is a child of the `BaseRNN` and `torch.nn.Module` class and takes as required arguments:
# 1. `spice_config (SpiceConfig)`: previously defined SpiceConfig object
# 2. `n_actions (int)`: number of possible actions in your dataset (including non-displayed ones if applicable).
# 3. `n_participants (int)`: number of participants in your dataset.
#
# As usual for a `torch.nn.Module` we have to define at least the `__init__` method and the `forward` method.
# The `forward` method gets called when computing a forward pass through the model and takes as inputs `(inputs (SpiceDataset.xs), prev_state (dict, default: None), batch_first (bool, default: False))` and returns `(logits (torch.Tensor, shape: (n_participants*n_blocks*n_experiments, timesteps, n_actions)), updated_state (dict))`. Two necessary method calls inside the forward pass are:
# 1. `self.init_forward_pass(inputs, prev_state, batch_first) -> SpiceSignals`: returns a `SpiceSignals` object which carries all relevant information already processed.
# 2. `self.post_forward_pass(SpiceSignals, batch_first) -> SpiceSignals`: does some re-arranging of the logits to adhere to `batch_first`.

# %%
spice_config = SpiceConfig(
    library_setup={
        'reward_environment': (
            'reward[t]',
            # 'reward[t-1]',
            # 'reward[t-2]',
            ),
        'reward_patch_harvest': (
            'reward[t]',
            # 'reward[t-1]',
            # 'reward[t-2]',
            ),
        'reward_patch_exit': (
            # 'reward[t-1]',
            # 'reward[t-2]',
            ),
        'depletion_patch_harvest': (
            'dreward[t]', 
            # 'dreward[t-1]',
            # 'dreward[t-2]',
            ),
        'depletion_patch_exit': (
            # 'dreward[t-1]',
            # 'dreward[t-2]',
            ),
        'continuation_patch': (
            'action[t-1]',
            # 'action[t-2]',
            ),
        # 'continuation_patch_harvest': (
        #     'action[t-1]',
        #     # 'action[t-2]',
        #     ),
        # 'continuation_patch_exit': (
        #     # 'action[t-1]',
        #     # 'action[t-2]',
        #     ),
    },
    memory_state={
        'value_reward_environment': 0.5,
        'value_reward_patch': 0.5,
        'value_depletion_patch': 0,
        'value_continuation_patch': 0,
        'reward[t-1]': 1,
        'action[t-1]': 0,
    },
    states_in_logit=(
        'value_reward_environment',
        'value_reward_patch',
        'value_depletion_patch',
        'value_continuation_patch',
    ),
)

# %%
class SpiceModel(BaseRNN):
    
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        
        self.dropout = 0.1
        
        self.participant_embedding = self.setup_embedding(
            num_embeddings=self.n_participants,
            embedding_size=self.embedding_size,
            dropout=self.dropout,
        )
        
        self.setup_module(key_module='reward_environment', input_size=1 + self.embedding_size, include_state=True)        
        self.setup_module(key_module='reward_patch_harvest', input_size=1 + self.embedding_size, include_state=True)
        self.setup_module(key_module='reward_patch_exit', input_size=self.embedding_size, include_state=True)
        
        self.setup_module(key_module='depletion_patch_harvest', input_size=1 + self.embedding_size, include_state=True)
        self.setup_module(key_module='depletion_patch_exit', input_size=0 + self.embedding_size, include_state=True)

        self.setup_module(key_module='continuation_patch', input_size=1 + self.embedding_size, include_state=True)        
        
    def forward(self, inputs, prev_state=None, batch_first=True):
        
        spice_signals = self.init_forward_pass(inputs, prev_state, batch_first)
        
        # used to update only the action value for harvesting. the action value for exit is kept at 0 as a reference point like in the MVT. 
        mask_harvest_value = torch.zeros_like(spice_signals.actions[0])
        mask_harvest_value[..., 0] = 1
        
        action_harvest = spice_signals.actions[..., 0].unsqueeze(-1).expand_as(spice_signals.actions)
        action_exit = spice_signals.actions[..., 1].unsqueeze(-1).expand_as(spice_signals.actions)
        rewards = spice_signals.rewards[..., 0].unsqueeze(-1).expand_as(spice_signals.actions)
        
        participant_embedding = self.participant_embedding(spice_signals.participant_ids)
                
        for trial in spice_signals.trials:
            
            harvested = action_harvest[trial] * mask_harvest_value
            exited = action_exit[trial] * mask_harvest_value

            # 1. Reward processing
            # learning average reward value of environment (only information accumulation; no exit information)
            self.call_module(
                key_module='reward_environment',
                key_state='value_reward_environment',
                action_mask=harvested,
                inputs=(
                    rewards[trial],
                    # self.state['reward[t-1]'],
                    # self.state['reward[t-2]'],
                    ),
                participant_index=spice_signals.participant_ids,
                participant_embedding=participant_embedding,
            )
            
            # learning current patch reward → patch valuation
            self.call_module(
                key_module='reward_patch_harvest',
                key_state='value_reward_patch',
                action_mask=harvested,
                inputs=(
                    rewards[trial],
                    # self.state['reward[t-1]'],
                    # self.state['reward[t-2]'],
                    ),
                participant_index=spice_signals.participant_ids,
                participant_embedding=participant_embedding,
            )
            
            self.call_module(
                key_module='reward_patch_exit',
                key_state='value_reward_patch',
                action_mask=exited,
                inputs=None,
                participant_index=spice_signals.participant_ids,
                participant_embedding=participant_embedding,
            )
            
            
            # 2. Depletion processing
            # depletion mask: only update if previous action was harvest (valid dreward)
            # prev_was_harvest = (self.state['action[t-1]'][..., 0:1] > 0.5).float().expand_as(harvested)
            # mask_depletion_harvest = harvested * prev_was_harvest
            
            # learning current patch depletion → exhaustion signal
            self.call_module(
                key_module='depletion_patch_harvest',
                key_state='value_depletion_patch',
                action_mask=harvested,#mask_depletion_harvest,
                inputs=(
                    rewards[trial]-self.state['reward[t-1]'],
                    ),
                participant_index=spice_signals.participant_ids,
                participant_embedding=participant_embedding,
            )
            
            self.call_module(
                key_module='depletion_patch_exit',
                key_state='value_depletion_patch',
                action_mask=exited,
                inputs=None,
                participant_index=spice_signals.participant_ids,
                participant_embedding=participant_embedding,
            )
            
            
            # 3. Continuation effect (e.g. pressure to exit to get to a fresh patch; reward/depletion agnostic)
            self.call_module(
                key_module='continuation_patch',
                key_state='value_continuation_patch',
                action_mask=None,
                inputs=(
                    spice_signals.actions[trial],
                    # self.state['action[t-1]'],
                    ),
                participant_index=spice_signals.participant_ids,
                participant_embedding=participant_embedding,
            )
            
            # self.call_module(
            #     key_module='continuation_patch_exit',
            #     key_state='value_continuation_patch',
            #     action_mask=exited,
            #     inputs=None,
            #     participant_index=spice_signals.participant_ids,
            #     participant_embedding=participant_embedding,
            # )
            
            
            # 4. Heuristical memory state updating
            
            # prev_reward: store current reward if harvested, reset to -1 otherwise
            # (only harvesting yields a reward; exiting does not)
            self.state['reward[t-1]'] = torch.where(harvested > 0.5, rewards[trial], 1)
            
            # prev_action: store current trial's action for use in the next trial
            self.state['action[t-1]'] = spice_signals.actions[trial]

            # working memory updates
            # self.state['reward[t-2]'] = torch.where(harvested>0.5, self.state['reward[t-1]'], 0)
            # self.state['reward[t-1]'] = torch.where(harvested>0.5, reward, 0)
            
            # 4. Logit computation
            spice_signals.logits[trial] = (
                + self.state['value_reward_environment']
                + self.state['value_reward_patch']
                + self.state['value_depletion_patch']
                + self.state['value_continuation_patch']
            )
        
        spice_signals = self.post_forward_pass(spice_signals, batch_first)
        
        return spice_signals.logits, self.get_state()

# %% [markdown]
# ## SPICE Training

# %% [markdown]
# Let's setup now the `SpiceEstimator` object and fit it to the data!
#
# We are going to do this in two steps:
#
# 1. Without fitting the SINDy coefficients to get the pure RNN performance given the selected architecture.
# 2. With fitting SINDy coefficients to get the final performance of the interpretable model
#
# That way we can disentangle the gap between GRU and SPICE w.r.t. architecture and SINDy library

# %%
# fitting without SINDy coefficients

estimator = SpiceEstimator(
        # model paramaeters
        spice_class=SpiceModel,
        spice_config=spice_config,
        n_actions=n_actions,
        n_participants=n_participants,
        n_experiments=1,
        
        epochs=0,
        warmup_steps=200,
        ensemble_size=10,
        
        sindy_weight=0,
        sindy_library_polynomial_degree=2,
        sindy_alpha=0.0001,
        sindy_pruning_frequency=100,
        sindy_ensemble_pruning=0.05,
        sindy_threshold_pruning=0.01,
        
        verbose=True,
    )
estimator.fit(dataset_train.xs, dataset_train.ys, dataset_test.xs, dataset_test.ys)
# Out:
# ================================================================================================================================================================
#  46%|████████████████████████████▉                                  | 459/1000 [28:36<33:43,  3.74s/it, L(Train)=0.1913585, L(Val,RNN)=0.2141900, Conv=8.68e-04]
# ================================================================================================================================================================
#
# Training interrupted. Continuing with further operations...
#
# ================================================================================
# Stage 2: SINDy refit
# ================================================================================
#  20%|██        | 201/1000 [02:17<09:15,  1.44it/s, loss=1.0755435, n_params=30.00+/-0.00]
# Ensemble confidence filtering:
# 	reward_environment: 1500 -> 413 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 1500 -> 893 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 750 -> 250 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 1500 -> 920 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 750 -> 485 / 750 (participant, experiment, term) slots
# 	continuation_patch: 1500 -> 10 / 1500 (participant, experiment, term) slots
#  30%|███       | 301/1000 [03:26<08:00,  1.46it/s, loss=0.7226014, n_params=29.99+/-0.09]
# Ensemble confidence filtering:
# 	reward_environment: 1500 -> 484 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 1500 -> 920 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 750 -> 246 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 1500 -> 887 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 750 -> 483 / 750 (participant, experiment, term) slots
# 	continuation_patch: 1500 -> 3 / 1500 (participant, experiment, term) slots
#  40%|████      | 401/1000 [04:34<06:49,  1.46it/s, loss=1.7103719, n_params=12.50+/-1.89]
# Ensemble confidence filtering:
# 	reward_environment: 495 -> 306 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 925 -> 877 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 260 -> 220 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 947 -> 782 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 488 -> 481 / 750 (participant, experiment, term) slots
# 	continuation_patch: 10 -> 0 / 1500 (participant, experiment, term) slots
#  50%|█████     | 501/1000 [05:42<05:45,  1.44it/s, loss=1.4716820, n_params=12.18+/-1.86]
# Ensemble confidence filtering:
# 	reward_environment: 485 -> 304 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 921 -> 853 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 255 -> 219 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 896 -> 720 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 484 -> 480 / 750 (participant, experiment, term) slots
# 	continuation_patch: 3 -> 0 / 1500 (participant, experiment, term) slots
#  60%|██████    | 601/1000 [06:50<04:32,  1.47it/s, loss=1.4676285, n_params=10.75+/-2.08]
# Ensemble confidence filtering:
# 	reward_environment: 319 -> 253 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 877 -> 829 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 222 -> 216 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 788 -> 655 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 482 -> 474 / 750 (participant, experiment, term) slots
# 	continuation_patch: 0 -> 0 / 1500 (participant, experiment, term) slots
#  70%|███████   | 701/1000 [07:58<03:22,  1.48it/s, loss=1.3860475, n_params=10.33+/-2.09]
# Ensemble confidence filtering:
# 	reward_environment: 307 -> 239 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 853 -> 798 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 219 -> 210 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 725 -> 610 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 480 -> 467 / 750 (participant, experiment, term) slots
# 	continuation_patch: 0 -> 0 / 1500 (participant, experiment, term) slots
#  80%|████████  | 801/1000 [09:07<02:15,  1.47it/s, loss=1.3526273, n_params=9.69+/-2.16]
# Ensemble confidence filtering:
# 	reward_environment: 253 -> 223 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 829 -> 775 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 216 -> 203 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 656 -> 576 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 474 -> 464 / 750 (participant, experiment, term) slots
# 	continuation_patch: 0 -> 0 / 1500 (participant, experiment, term) slots
#  90%|█████████ | 901/1000 [10:15<01:07,  1.47it/s, loss=1.3254932, n_params=9.29+/-2.17]
# Ensemble confidence filtering:
# 	reward_environment: 240 -> 216 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 798 -> 756 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 210 -> 202 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 615 -> 547 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 468 -> 454 / 750 (participant, experiment, term) slots
# 	continuation_patch: 0 -> 0 / 1500 (participant, experiment, term) slots
# 100%|██████████| 1000/1000 [11:22<00:00,  1.46it/s, loss=1.3234317, n_params=8.93+/-2.11]
# ================================================================================
# Training results:
# 	L(Train, RNN): 0.0000000
# 	L(Val, RNN):   0.2141900
# ================================================================================
#
# RNN training finished.
# Training took 2404.80 seconds.

# %%
path_spice = 'params/spice_bustamante2023.pkl'

estimator = SpiceEstimator(
        # model paramaeters
        spice_class=SpiceModel,
        spice_config=spice_config,
        n_actions=2,
        n_participants=n_participants,
        n_experiments=1,
        
        epochs=1000,
        warmup_steps=200,
        ensemble_size=10,
        
        sindy_weight=0.1,
        sindy_alpha=0.0001,
        sindy_pruning_frequency=100,
        sindy_threshold_pruning=0.01,
        sindy_ensemble_pruning=0.05,
        sindy_library_polynomial_degree=2,
        
        device = torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
        verbose=True,
        save_path_spice=path_spice,
    )

# %%
estimator.fit(dataset_train.xs, dataset_train.ys, dataset_train.xs, dataset_train.ys)
# Out:
# ================================================================================================================================================================
# 100%|██████████████████████████████████████| 1000/1000 [49:35<00:00,  2.98s/it, L(Train)=0.2104396, L(Val,RNN)=0.2201012, L(Val,SINDy)=0.2275555, Conv=2.57e-04]
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# SPICE Model (Coefficients: 16):
# reward_environment[t+1]      = 0.497 reward_environment[t] + 0.993 reward[t] + -0.041 reward_environment^2 + 1.408 reward[t]^2
# reward_patch_harvest[t+1]    = 0.943 reward_patch_harvest[t]
# reward_patch_exit[t+1]       = 0.269 1 + 1.0 reward_patch_exit[t]
# depletion_patch_harvest[t+1] = 0.603 1 + 0.461 depletion_patch_harvest[t] + 1.395 dreward[t] + 0.051 depletion_patch_harvest^2 + 0.578 depletion_patch_harvest*dreward[t]
# depletion_patch_exit[t+1]    = 2.354 1 + 1.274 depletion_patch_exit[t]
# continuation_patch[t+1]      = 0.651 continuation_patch[t] + -0.405 action[t-1] + -0.166 action[t-1]^2
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Pruning patience:
# reward_environment:      -, 0, 0, 0, -, 0
# reward_patch_harvest:    -, 1, -, -, -, -
# reward_patch_exit:       0, -, -
# depletion_patch_harvest: 0, 0, 0, 0, 0, -
# depletion_patch_exit:    0, 0, -
# continuation_patch:      -, 0, 0, -, -, 0
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------
# Term presence across SPICE models (number of models=250):
# reward_environment:      191, 249, 249, 153, 136, 250
# reward_patch_harvest:    207, 223, 209, 9, 93, 221
# reward_patch_exit:       229, 34, 0
# depletion_patch_harvest: 249, 250, 199, 145, 250, 0
# depletion_patch_exit:    250, 235, 122
# continuation_patch:      2, 177, 178, 5, 0, 81
# ================================================================================================================================================================
# Maximum number of training epochs reached.
# Model did not converge yet.
#
# ================================================================================
# Stage 2: SINDy refit
# ================================================================================
#  20%|██        | 202/1000 [00:37<02:30,  5.31it/s, loss=0.0419015, n_params=18.34+/-3.11]
# Ensemble confidence filtering:
# 	reward_environment: 1228 -> 1127 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 962 -> 947 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 263 -> 244 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 1093 -> 1072 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 607 -> 607 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  30%|███       | 302/1000 [00:56<02:11,  5.33it/s, loss=0.0294898, n_params=17.96+/-2.98]
# Ensemble confidence filtering:
# 	reward_environment: 1225 -> 1134 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 958 -> 951 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 259 -> 247 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 1092 -> 975 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 607 -> 606 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  40%|████      | 402/1000 [01:15<01:52,  5.30it/s, loss=0.0210298, n_params=17.42+/-2.63]
# Ensemble confidence filtering:
# 	reward_environment: 1162 -> 1100 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 953 -> 949 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 247 -> 245 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 1081 -> 944 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 607 -> 604 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  50%|█████     | 502/1000 [01:34<01:34,  5.30it/s, loss=0.0201837, n_params=17.11+/-2.63]
# Ensemble confidence filtering:
# 	reward_environment: 1146 -> 1062 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 951 -> 947 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 247 -> 245 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 976 -> 934 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 606 -> 595 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  60%|██████    | 602/1000 [01:53<01:14,  5.32it/s, loss=0.0179926, n_params=16.87+/-2.58]
# Ensemble confidence filtering:
# 	reward_environment: 1100 -> 1031 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 949 -> 948 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 245 -> 244 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 945 -> 928 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 604 -> 587 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  70%|███████   | 702/1000 [02:11<00:56,  5.30it/s, loss=0.0141451, n_params=16.68+/-2.51]
# Ensemble confidence filtering:
# 	reward_environment: 1062 -> 1028 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 948 -> 946 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 245 -> 244 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 934 -> 924 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 595 -> 583 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  80%|████████  | 802/1000 [02:30<00:37,  5.32it/s, loss=0.0115893, n_params=16.62+/-2.50]
# Ensemble confidence filtering:
# 	reward_environment: 1031 -> 1022 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 948 -> 941 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 244 -> 243 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 928 -> 922 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 587 -> 568 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
#  90%|█████████ | 902/1000 [02:49<00:18,  5.28it/s, loss=0.0113244, n_params=16.52+/-2.50]
# Ensemble confidence filtering:
# 	reward_environment: 1028 -> 1017 / 1500 (participant, experiment, term) slots
# 	reward_patch_harvest: 946 -> 939 / 1500 (participant, experiment, term) slots
# 	reward_patch_exit: 244 -> 243 / 750 (participant, experiment, term) slots
# 	depletion_patch_harvest: 924 -> 921 / 1500 (participant, experiment, term) slots
# 	depletion_patch_exit: 583 -> 547 / 750 (participant, experiment, term) slots
# 	continuation_patch: 443 -> 443 / 1500 (participant, experiment, term) slots
# 100%|██████████| 1000/1000 [03:07<00:00,  5.32it/s, loss=0.0091453, n_params=16.53+/-2.51]
# ================================================================================
# Training results:
# 	L(Train, RNN): 0.2104396
# 	L(Val, RNN):   0.2201012
# 	L(Val, SINDy): 0.2363280
# ================================================================================
#
# RNN training finished.
# Training took 3164.54 seconds.
# Saving SPICE model to ../params/bustamante2023/spice_bustamante2023.pkl...

# %%
estimator.load_spice(path_spice)

# %%
# Print example SPICE model for first participant
print("\nExample SPICE model (participant 0):")
estimator.print_spice_model(participant_id=0)
# Out:
# Example SPICE model (participant 0):
# reward_environment[t+1]      = 0.357 reward_environment[t] + 1.336 reward[t] + 1.151 reward[t]^2
# reward_patch_harvest[t+1]    = 1.0 reward_patch_harvest[t]
# reward_patch_exit[t+1]       = 1.0 reward_patch_exit[t]
# depletion_patch_harvest[t+1] = 0.383 1 + 0.67 depletion_patch_harvest[t] + 0.823 dreward[t] + 0.584 depletion_patch_harvest*dreward[t]
# depletion_patch_exit[t+1]    = 1.524 1 + 2.098 depletion_patch_exit[t]
# continuation_patch[t+1]      = 0.652 continuation_patch[t] + -0.346 action[t-1] + -0.232 action[t-1]^2

# %% [markdown]
# ## Benchmarking

# %% [markdown]
# ### MVT Model by Constantino et al. (2015)

# %%
# 1. stick to low effort 
# 2. two sets of params for low and high effort

mvt = MarginalValueTheoremModel(
    n_participants=n_participants,
    depletion=None,  # if None: learn value; else: fix to given value;
    baseline_gain=None,  # if None: learn value; else: fix to given value;
    batch_first=True,
    )

path_mvt = path_spice.replace('spice_', 'mvt_')

# %%
epochs = 1000
optimizer = torch.optim.Adam(params=mvt.parameters(), lr=0.01)

mvt = training(
    model=mvt,
    optimizer=optimizer,
    epochs=epochs,
    dataset_train=dataset_train,
    dataset_test=dataset_test,
    device=torch.device('cpu'),
)

torch.save(mvt.state_dict(), path_mvt)
# Out:
# Epoch 1/1000: L(Train): 0.7178359627723694; L(Test): 0.7133145928382874
# Epoch 2/1000: L(Train): 0.7128833532333374; L(Test): 0.708382248878479
# Epoch 3/1000: L(Train): 0.7079785466194153; L(Test): 0.7034977674484253
# Epoch 4/1000: L(Train): 0.7031217217445374; L(Test): 0.6986619234085083
# Epoch 5/1000: L(Train): 0.6983134150505066; L(Test): 0.6938748955726624
# Epoch 6/1000: L(Train): 0.6935540437698364; L(Test): 0.6891371607780457
# Epoch 7/1000: L(Train): 0.6888440251350403; L(Test): 0.6844491362571716
# Epoch 8/1000: L(Train): 0.6841834783554077; L(Test): 0.6798110008239746
# Epoch 9/1000: L(Train): 0.6795729994773865; L(Test): 0.6752229332923889
# Epoch 10/1000: L(Train): 0.6750121116638184; L(Test): 0.6706851124763489
# Epoch 11/1000: L(Train): 0.6705018877983093; L(Test): 0.6661975383758545
# Epoch 12/1000: L(Train): 0.6660416126251221; L(Test): 0.661760151386261
# Epoch 973/1000: L(Train): 0.30362674593925476; L(Test): 0.2999219596385956
# Epoch 974/1000: L(Train): 0.3036119043827057; L(Test): 0.29990747570991516
# Epoch 975/1000: L(Train): 0.3035971224308014; L(Test): 0.29989296197891235
# Epoch 976/1000: L(Train): 0.3035823404788971; L(Test): 0.29987847805023193
# Epoch 977/1000: L(Train): 0.3035676181316376; L(Test): 0.2998639941215515
# Epoch 978/1000: L(Train): 0.30355289578437805; L(Test): 0.29984959959983826
# Epoch 979/1000: L(Train): 0.3035382032394409; L(Test): 0.2998351752758026
# Epoch 980/1000: L(Train): 0.30352354049682617; L(Test): 0.29982081055641174
# Epoch 981/1000: L(Train): 0.3035089671611786; L(Test): 0.29980647563934326
# Epoch 982/1000: L(Train): 0.3034943640232086; L(Test): 0.2997921407222748
# Epoch 983/1000: L(Train): 0.30347976088523865; L(Test): 0.2997778058052063
# Epoch 984/1000: L(Train): 0.30346521735191345; L(Test): 0.2997635006904602
# Epoch 985/1000: L(Train): 0.30345070362091064; L(Test): 0.2997492849826813
# Epoch 986/1000: L(Train): 0.30343618988990784; L(Test): 0.29973500967025757
# Epoch 987/1000: L(Train): 0.30342164635658264; L(Test): 0.29972079396247864
# Epoch 988/1000: L(Train): 0.3034072518348694; L(Test): 0.2997065782546997
# Epoch 989/1000: L(Train): 0.30339276790618896; L(Test): 0.29969242215156555
# Epoch 990/1000: L(Train): 0.3033784329891205; L(Test): 0.2996782958507538
# Epoch 991/1000: L(Train): 0.30336400866508484; L(Test): 0.29966413974761963
# Epoch 992/1000: L(Train): 0.30334964394569397; L(Test): 0.29965001344680786
# Epoch 993/1000: L(Train): 0.3033352792263031; L(Test): 0.2996358871459961
# Epoch 994/1000: L(Train): 0.3033209443092346; L(Test): 0.2996218204498291
# Epoch 995/1000: L(Train): 0.3033066391944885; L(Test): 0.2996077835559845
# Epoch 996/1000: L(Train): 0.30329233407974243; L(Test): 0.2995937168598175
# Epoch 997/1000: L(Train): 0.3032780587673187; L(Test): 0.2995797097682953
# Epoch 998/1000: L(Train): 0.3032638132572174; L(Test): 0.29956570267677307
# Epoch 999/1000: L(Train): 0.3032495677471161; L(Test): 0.29955169558525085
# Epoch 1000/1000: L(Train): 0.30323538184165955; L(Test): 0.2995377480983734

# %%
mvt.load_state_dict(torch.load(path_mvt, map_location='cpu'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### GRU Model

# %%
from weinhardt2026.utils.benchmarking_gru import Model as GRU

gru = GRU(n_actions)

path_gru = 'params/gru_bustamante2023.pkl'

# %%
epochs = 1000
optimizer = torch.optim.Adam(gru.parameters(), lr=0.01)

gru = training(
    model=gru,
    optimizer=optimizer,
    dataset_train=dataset_train,
    dataset_test=dataset_test,
    epochs=epochs,
    ).to(torch.device('cpu'))

torch.save(gru.state_dict(), path_gru)

# %%
gru.load_state_dict(torch.load(path_gru, map_location='cpu'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# # ANALYSIS

# %%
from weinhardt2026.analysis.analysis_model_evaluation import analysis_model_evaluation
from weinhardt2026.analysis.analysis_coefficients_distributions import analysis_coefficients_distributions
from weinhardt2026.analysis.analysis_coefficients_individuals import analysis_coefficients_individuals

# %% [markdown]
# ## General analysis

# %%
df = pd.read_csv(path_data)
df['last_reward'] = df.groupby('subject_id')['last_reward'].fillna(method='bfill')
df['participant_id'] = pd.factorize(df['subject_id'])[0]
exit_df = df[df['decision'] == 1]
mean_exit_threshold = exit_df.groupby(['participant_id', 'subject_id'])['last_reward'].mean().reset_index()
mean_exit_threshold['relative_optimal'] = mean_exit_threshold['last_reward'] - 6.78 #from Bustamante et al. Table S7, experiment 1
mean_exit_threshold['over_harvester'] = np.where(mean_exit_threshold['relative_optimal'] <= 0, 1, 0)
print(mean_exit_threshold)
overharvesters = mean_exit_threshold[mean_exit_threshold['over_harvester'] == 1]['participant_id'].unique()
underharvesters = mean_exit_threshold[mean_exit_threshold['over_harvester'] == 0]['participant_id'].unique()

print('OVERHARVESTERS') 
for p in overharvesters:
    print('Participant number', p)
    estimator.print_spice_model(participant_id=p)

print('UNDERHARVESTERS') 
for p in underharvesters:
    print('Participant number', p)
    estimator.print_spice_model(participant_id=p)

# %%
print("Fitted MVT parameters:")
print("\nAlpha")
print(mvt.alpha_env)
print("\nBeta")
print(mvt.beta)
print("\nC")
print(mvt.c)
print("\nBaseline Gain")
print(mvt.baseline_gain)
print("\nDepletion")
print(mvt.depletion)

# %% [markdown]
# ## Analysis model evaluation

# %%
analysis_model_evaluation(
    dataset=dataset_test,
    spice_model=estimator,
    benchmark_model=mvt.to(torch.device('cpu')),
    gru_model=gru.to(torch.device('cpu')),
)
# Out:
# Computing choice probabilities with benchmark model...
# Computing choice probabilities with GRU model...
# Computing choice probabilities with SPICE model...
#            Trial Lik.     (std)  n_parameters     (std)       NLL     (std)  \
# Benchmark    0.741161  0.075834         5.000  0.000000  0.299538  0.108399
# GRU          0.822435  0.063307      1746.000  0.000000  0.195486  0.081771
# SPICE-RNN    0.808581  0.067879     87132.000  0.000000  0.212474  0.090894
# SPICE        0.800555  0.076847        16.528  2.510328  0.222450  0.107735
#
#                    AIC          BIC
# Benchmark     0.723657     0.871379
# GRU          43.894932    95.479637
# SPICE-RNN  2171.437256  4745.707031
# SPICE         0.856794     1.345287

# %% [markdown]
# ## Analysis coefficient distributions

# %%
analysis_coefficients_distributions(
    spice_model=estimator,
    output_dir='results',
)
# Out:
# Extracting coefficient data...
#   Ensemble=10, Participants=250, Experiments=1, Modules=6, Total terms=30
#
# ============================================================
# ANALYSIS 1: Ensemble Consistency
# ============================================================
#   Mean presence agreement: 1.000
#   Mean presence rate:      0.552
#   Mean CV:                 0.421
#   Ensemble spread plots saved.
#   Ensemble CV heatmaps saved.
#
# ============================================================
# ANALYSIS 2: Coefficient Distributions
# ============================================================
#   Terms with >50% presence: 17 / 30
#   Terms with 0% presence:   3 / 30
#   Violin plots saved.
#   Presence rate bar chart saved.
#   Experiment comparison skipped (X=1).
#   Sparsity heatmaps saved.
#
# All results saved to: results
# (                     module                                term  term_index  \
#  0        reward_environment                                   1           0
#  1        reward_environment                  reward_environment           1
#  2        reward_environment                           reward[t]           2
#  3        reward_environment                reward_environment^2           3
#  4        reward_environment        reward_environment*reward[t]           4
#  5        reward_environment                         reward[t]^2           5
#  6      reward_patch_harvest                                   1           0
#  7      reward_patch_harvest                reward_patch_harvest           1
#  8      reward_patch_harvest                           reward[t]           2
#  9      reward_patch_harvest              reward_patch_harvest^2           3
#  10     reward_patch_harvest      reward_patch_harvest*reward[t]           4
#  11     reward_patch_harvest                         reward[t]^2           5
#  12        reward_patch_exit                                   1           0
#  13        reward_patch_exit                   reward_patch_exit           1
#  14        reward_patch_exit                 reward_patch_exit^2           2
#  15  depletion_patch_harvest                                   1           0
#  16  depletion_patch_harvest             depletion_patch_harvest           1
#  17  depletion_patch_harvest                          dreward[t]           2
#  18  depletion_patch_harvest           depletion_patch_harvest^2           3
#  19  depletion_patch_harvest  depletion_patch_harvest*dreward[t]           4
#  20  depletion_patch_harvest                        dreward[t]^2           5
#  21     depletion_patch_exit                                   1           0
#  22     depletion_patch_exit                depletion_patch_exit           1
#  23     depletion_patch_exit              depletion_patch_exit^2           2
#  24       continuation_patch                                   1           0
#  25       continuation_patch                  continuation_patch           1
#  26       continuation_patch                         action[t-1]           2
#  27       continuation_patch                continuation_patch^2           3
#  28       continuation_patch      continuation_patch*action[t-1]           4
#  29       continuation_patch                       action[t-1]^2           5
#
#      presence_agreement_mean  presence_agreement_std  presence_rate_mean  \
#  0                       1.0                     0.0               0.384
#  1                       1.0                     0.0               0.996
#  2                       1.0                     0.0               0.996
#  3                       1.0                     0.0               0.168
#  4                       1.0                     0.0               0.544
#  5                       1.0                     0.0               1.000
#  6                       1.0                     0.0               0.816
#  7                       1.0                     0.0               0.876
#  8                       1.0                     0.0               0.812
#  9                       1.0                     0.0               0.024
#  10                      1.0                     0.0               0.360
#  11                      1.0                     0.0               0.876
#  12                      1.0                     0.0               0.900
#  13                      1.0                     0.0               0.072
#  14                      1.0                     0.0               0.000
#  15                      1.0                     0.0               0.960
#  16                      1.0                     0.0               0.996
#  17                      1.0                     0.0               0.732
#  18                      1.0                     0.0               0.008
#  19                      1.0                     0.0               0.992
#  20                      1.0                     0.0               0.000
#  21                      1.0                     0.0               1.000
#  22                      1.0                     0.0               0.940
#  23                      1.0                     0.0               0.332
#  24                      1.0                     0.0               0.008
#  25                      1.0                     0.0               0.708
#  26                      1.0                     0.0               0.712
#  27                      1.0                     0.0               0.020
#  28                      1.0                     0.0               0.000
#  29                      1.0                     0.0               0.324
#
#      presence_rate_std   cv_mean  cv_median  ensemble_std_mean  \
#  0            0.486358  0.473267   0.334216           0.164066
#  1            0.063119  0.151818   0.123147           0.083427
#  2            0.063119  0.188419   0.179626           0.231906
#  3            0.373866  0.470503   0.357648           0.017953
#  4            0.498060  0.363816   0.323015           0.109976
#  5            0.000000  0.151512   0.100271           0.186644
#  6            0.387484  0.369964   0.316519           0.193588
#  7            0.329582  0.263651   0.213009           0.099023
#  8            0.390712  0.233509   0.161315           0.245330
#  9            0.153049  0.513046   0.471280           0.007748
#  10           0.480000  0.603801   0.561016           0.088301
#  11           0.329582  0.338401   0.271386           0.329353
#  12           0.300000  0.336848   0.276343           0.442113
#  13           0.258488  0.764613   0.726326           0.366458
#  14           0.000000       NaN        NaN                NaN
#  15           0.195959  0.267041   0.249849           0.096762
#  16           0.063119  0.183105   0.169920           0.046249
#  17           0.442918  0.518490   0.414870           0.477282
#  18           0.089084  0.258259   0.258259           0.029856
#  19           0.089084  0.224600   0.200075           0.131810
#  20           0.000000       NaN        NaN                NaN
#  21           0.000000  0.127262   0.115262           0.224589
#  22           0.237487  0.162086   0.110148           0.158754
#  23           0.470931  2.075099   1.311654           0.271756
#  24           0.089084  0.557401   0.557401           0.016190
#  25           0.454682  0.329003   0.279668           0.090295
#  26           0.452831  0.401724   0.351260           0.148012
#  27           0.140000  0.585957   0.536584           0.176091
#  28           0.000000       NaN        NaN                NaN
#  29           0.468000  0.443470   0.397361           0.183249
#
#      ensemble_mean_mean
#  0            -0.398593
#  1            -0.606479
#  2             1.384957
#  3            -0.032797
#  4             0.371146
#  5             1.424372
#  6            -0.604709
#  7            -0.393375
#  8             1.266709
#  9            -0.015657
#  10            0.157333
#  11            1.088777
#  12            1.437129
#  13           -0.525127
#  14                 NaN
#  15            0.376284
#  16           -0.252852
#  17            1.180475
#  18           -0.118624
#  19            0.599881
#  20                 NaN
#  21            1.689543
#  22            1.082866
#  23            0.287291
#  24            0.028246
#  25           -0.261287
#  26           -0.400872
#  27            0.301969
#  28                 NaN
#  29           -0.420544  ,
#                       module                                term  term_index  \
#  0        reward_environment                                   1           0
#  1        reward_environment                  reward_environment           1
#  2        reward_environment                           reward[t]           2
#  3        reward_environment                reward_environment^2           3
#  4        reward_environment        reward_environment*reward[t]           4
#  5        reward_environment                         reward[t]^2           5
#  6      reward_patch_harvest                                   1           0
#  7      reward_patch_harvest                reward_patch_harvest           1
#  8      reward_patch_harvest                           reward[t]           2
#  9      reward_patch_harvest              reward_patch_harvest^2           3
#  10     reward_patch_harvest      reward_patch_harvest*reward[t]           4
#  11     reward_patch_harvest                         reward[t]^2           5
#  12        reward_patch_exit                                   1           0
#  13        reward_patch_exit                   reward_patch_exit           1
#  14        reward_patch_exit                 reward_patch_exit^2           2
#  15  depletion_patch_harvest                                   1           0
#  16  depletion_patch_harvest             depletion_patch_harvest           1
#  17  depletion_patch_harvest                          dreward[t]           2
#  18  depletion_patch_harvest           depletion_patch_harvest^2           3
#  19  depletion_patch_harvest  depletion_patch_harvest*dreward[t]           4
#  20  depletion_patch_harvest                        dreward[t]^2           5
#  21     depletion_patch_exit                                   1           0
#  22     depletion_patch_exit                depletion_patch_exit           1
#  23     depletion_patch_exit              depletion_patch_exit^2           2
#  24       continuation_patch                                   1           0
#  25       continuation_patch                  continuation_patch           1
#  26       continuation_patch                         action[t-1]           2
#  27       continuation_patch                continuation_patch^2           3
#  28       continuation_patch      continuation_patch*action[t-1]           4
#  29       continuation_patch                       action[t-1]^2           5
#
#          mean       std    median       iqr   min_val   max_val  presence_rate  \
#  0  -0.153060  0.278437  0.000000  0.339365 -0.852052  0.521245          0.384
#  1  -0.604053  0.239531 -0.637539  0.431149 -1.134403  0.000000          0.996
#  2   1.379418  0.292477  1.398558  0.306701  0.000000  2.065050          0.996
#  3  -0.005510  0.016676  0.000000  0.000000 -0.164803  0.053502          0.168
#  4   0.201903  0.244590  0.081404  0.427061 -0.209409  0.780778          0.544
#  5   1.424372  0.354131  1.384537  0.245335  0.185573  2.438984          1.000
#  6  -0.493443  0.307931 -0.528255  0.468777 -1.021662  0.000000          0.816
#  7  -0.344597  0.183221 -0.365694  0.262115 -0.680187  0.000000          0.876
#  8   1.028568  0.577605  1.231753  0.693801  0.000000  1.852437          0.812
#  9  -0.000376  0.002466  0.000000  0.000000 -0.020874  0.000000          0.024
#  10  0.056640  0.085941  0.000000  0.112718  0.000000  0.330231          0.360
#  11  0.953769  0.473962  1.028117  0.620292 -0.268463  1.813563          0.876
#  12  1.293416  0.528136  1.509485  0.360804 -0.418603  1.769591          0.900
#  13 -0.037809  0.150888  0.000000  0.000000 -0.915143  0.000000          0.072
#  14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000          0.000
#  15  0.361233  0.108821  0.361932  0.115767  0.000000  0.615711          0.960
#  16 -0.251840  0.108706 -0.222064  0.076133 -0.766522  0.000000          0.996
#  17  0.864108  0.708128  0.804280  1.472020  0.000000  2.412851          0.732
#  18 -0.000949  0.010873  0.000000  0.000000 -0.147213  0.000000          0.008
#  19  0.595082  0.173837  0.605963  0.168786  0.000000  1.341554          0.992
#  20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000          0.000
#  21  1.689543  0.434943  1.521813  0.517933  0.504332  3.152309          1.000
#  22  1.017894  0.334362  1.121869  0.420592  0.000000  1.350837          0.940
#  23  0.095381  0.257559  0.000000  0.100019 -0.017353  1.964824          0.332
#  24  0.000226  0.002612  0.000000  0.000000  0.000000  0.036061          0.008
#  25 -0.184991  0.150553 -0.195271  0.279806 -0.656495  0.000000          0.708
#  26 -0.285421  0.231809 -0.327555  0.481846 -1.034720  0.000000          0.712
#  27  0.006039  0.042327  0.000000  0.000000  0.000000  0.321979          0.020
#  28  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000          0.000
#  29 -0.136256  0.206178  0.000000  0.323925 -0.604685  0.000000          0.324
#
#      n_nonzero  n_total
#  0          96      250
#  1         249      250
#  2         249      250
#  3          42      250
#  4         136      250
#  5         250      250
#  6         204      250
#  7         219      250
#  8         203      250
#  9           6      250
#  10         90      250
#  11        219      250
#  12        225      250
#  13         18      250
#  14          0      250
#  15        240      250
#  16        249      250
#  17        183      250
#  18          2      250
#  19        248      250
#  20          0      250
#  21        250      250
#  22        235      250
#  23         83      250
#  24          2      250
#  25        177      250
#  26        178      250
#  27          5      250
#  28          0      250
#  29         81      250  ,
#  None)

# %% [markdown]
# ## Analysis Individual Differences

# %%
analysis_coefficients_individuals(
    criterion="SomeCriterionColumnInYourDataset",
    analysis="disc",  # also: "cont"
    reference="ReferenceGroupFromCriterionColumn",  # only necessary if analysis="disct"
    
    path_data=path_data,
    
    spice_model=estimator,
    
    dir_output='results'
)
